# %% [markdown]
# # Natural Language processing for Customer reviews for Hotels
# ## Trip Advisor Location: British Columbia
# ## City Code: 154922
# Project Scope: Review positive and negative reviews and attribute them to specific reasons for the reviews to better understand the nature of the hotel and the reason for sentiment.

# %%
import sys
print(sys.version)
# Out:
# 3.7.3 (default, Mar 27 2019, 16:54:48)
# [Clang 4.0.1 (tags/RELEASE_401/final)]

# %%
#Plot
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

#Data Packages
import math
import pandas as pd
import numpy as np

#Progress bar
from tqdm import tqdm

#Counter
from collections import Counter

#Operation
import operator
import csv

#Natural Language Processing Packages
import re
import nltk


## Download Resources
nltk.download("vader_lexicon")
nltk.download("stopwords")
nltk.download("averaged_perceptron_tagger")
nltk.download("wordnet")

from nltk.sentiment import SentimentAnalyzer
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from nltk.sentiment.util import *
from nltk import tokenize
from nltk.corpus import stopwords
from nltk.tag import PerceptronTagger
from nltk.data import find

## Machine Learning
import sklearn
import sklearn.metrics as metrics
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/krutheekarajkumar/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/krutheekarajkumar/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/krutheekarajkumar/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/krutheekarajkumar/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %% [markdown]
# ### Computing the average Vader sentiment and the average groun truth rating per hotel.
# NLTK sentiment analysis package (vader) used in conjecture with NLTK library. NLTK libraries allow for tokenization, parsing, classification, tagging. The library is primarily written in Python and therefore is easier to implement into this project.

# %%
file = "reviews2.csv"

# %%
with open(file, 'r',encoding='ascii') as f:
    reader = csv.reader(f)
    review = list(reader)

# %%
reviews_df = pd.read_csv(file, names=['Link', 'Hotel_Name', 'Review text', 'Ratings', 'Experience'], delimiter=',')
#reviews_df.columns('Link','Hotel Name','Review text','Ratings','Experience')
print("Number of reviews: ",reviews_df.shape[0])
# Out:
# Number of reviews:  4059

# %%
x = reviews_df['Hotel_Name'].unique()
print("Number of hotels being reviewed: ", len(x))
# Out:
# Number of hotels being reviewed:  78

# %% [markdown]
# <b> Function evalSentences: </b>Each of the Reviews were given three scores based on how positive, neutral or negative they were, these were compounded using the NLTK's polarity function. The values were then written into a dataframe which included the text of the review as well as the score associate with it for further analysis.

# %%
def evalSentences(sentences, to_df=False, columns=[2]):
    #Instantiate an instance to access SentimentIntensityAnalyzer class
    print("--- VADER SENTIMENTS ---")
    sid = SentimentIntensityAnalyzer()
    pdlist = []
    if to_df:
        for sentence in sentences:
            ss = sid.polarity_scores(sentence)
            pdlist.append([sentence]+[ss['compound']])
        reviewDf = pd.DataFrame(pdlist)
        reviewDf.columns = columns
        return reviewDf
    
    else:
        for sentence in sentences:
            ss = sid.polarity_scores(sentence)
            #print(ss)
            for k in sorted(ss):
                print('{0}: {1}, '.format(k, ss[k]), end='')      
            print()

# %%
vader_evaluated_sentenced = evalSentences(reviews_df['Review text'])
# Out:
# --- VADER SENTIMENTS ---
# compound: 0.8442, neg: 0.034, neu: 0.827, pos: 0.14,
# compound: 0.9965, neg: 0.011, neu: 0.83, pos: 0.159,
# compound: 0.9757, neg: 0.018, neu: 0.739, pos: 0.243,
# compound: 0.9766, neg: 0.0, neu: 0.799, pos: 0.201,
# compound: 0.4939, neg: 0.019, neu: 0.909, pos: 0.072,
# compound: 0.9842, neg: 0.0, neu: 0.763, pos: 0.237,
# compound: 0.98, neg: 0.0, neu: 0.798, pos: 0.202,
# compound: 0.8516, neg: 0.0, neu: 0.855, pos: 0.145,
# compound: 0.9924, neg: 0.0, neu: 0.789, pos: 0.211,
# compound: 0.9735, neg: 0.029, neu: 0.619, pos: 0.352,
# compound: 0.6697, neg: 0.046, neu: 0.793, pos: 0.161,
# compound: 0.9017, neg: 0.075, neu: 0.58, pos: 0.345,
# compound: 0.6369, neg: 0.0, neu: 0.625, pos: 0.375,
# compound: 0.9358, neg: 0.041, neu: 0.825, pos: 0.133,
# compound: 0.9786, neg: 0.0, neu: 0.577, pos: 0.423,
# compound: 0.9607, neg: 0.0, neu: 0.553, pos: 0.447,
# compound: 0.8625, neg: 0.0, neu: 0.904, pos: 0.096,
# compound: 0.9595, neg: 0.0, neu: 0.805, pos: 0.195,
# compound: 0.8316, neg: 0.019, neu: 0.878, pos: 0.103,
# compound: 0.9516, neg: 0.0, neu: 0.816, pos: 0.184,
# compound: 0.9657, neg: 0.0, neu: 0.863, pos: 0.137,
# compound: 0.9427, neg: 0.041, neu: 0.785, pos: 0.173,
# compound: 0.8716, neg: 0.029, neu: 0.822,

# %%
reviews = reviews_df['Review text'].values
reviewDF = evalSentences(reviews, to_df=True, columns=['reviewCol','vader'])

# %%
x = reviews_df["Experience"]
y = reviews_df['Hotel_Name']
reviewDF = pd.concat([reviewDF, x], axis=1)
reviewDF = pd.concat([reviewDF, y], axis=1)

# %%
reviewDF[reviewDF['Hotel_Name'] == 'Stansbury&#39;s Guest House']
# Out:
#                                             reviewCol   vader Experience  \
# 28  "Stayed for a week in the Stansbury\\'s guest ...  0.8682   positive
# 29  "A group of 6 of us stayed here for a weekend ...  0.9367   positive
# 30  "Visiting from New Zealand,we were fortunate t...  0.9652   positive
# 31  "Gwen and Scott have a beautiful Guest House a...  0.9803   positive
# 32  "A beautifully finished apartment with every c...  0.9807   positive
# 33  "We happended upon Stansbury\\'s last year jus...  0.9860   positive
# 34  "We stayed at Stansbury`s Guest House for 8 da...  0.9940   positive
# 35  "We had an amazing stay at the Stansbury\\'s G...  0.9665   positive
# 36  "Nine of us spent the weekend at the Stansbury...  0.9443   positive
# 37  "This place has: very friendly hosts, is super...  0.9588   positive
# 38  "Cumberland is cute little village in the Como...  0.9638   positive
# 39  "My wife and I stayed at Stansbury\\'s Guest H...  0.8962   positive
# 40  "You will not be disappointed!  The rooms and ...  0.8551   positive
# 41  "What a wonderful Guest House to call home for...  0.9273   positive
# 42  "This house was clean and had a beautiful sunn...  0.9716   positive
# 43  "My sister and I just spent 10 days at the Gue...  0.8937   positive
# 44  "I hardly want to share this gem so that Gwen\...  0.9757   positive
# 45  "What a great place!  1, 2, or 3 bedrooms.  Bi...  0.9864   positive
# 46  "Right from the beginning Stansbury\\'s Guest ...  0.9532   positive
# 47  "Gwen and Scott.\\n\\nOur stay was Fantastic!!...  0.9576   positive
# 48  "My husband and I stayed at Stansbury\\'s with...  0.9466   positive
# 49  "We have stayed at Stansbury\\'s Guest House a...  0.9744   positive
# 50  "I finally made my way to Cumberland and at th...  0.9836   positive
# 51  "Great location! Close to trails, pubs, food a...  0.9718   positive
# 52  "My Husband and I came for a mountain bike vac...  0.9895   positive
# 53  "Gwen &amp; Scott have created a wonderful san...  0.9897   positive
# 54  "Scott and Gwen made us very welcome. I rode w...  0.8761   positive
# 55  "The hosts are warm and inviting and the 3 bed...  0.9545   positive
# 56  "A perfect place to stay if you want a peacefu...  0.9700   positive
# 57  "Always on the lookout for interesting places ...  0.9881   positive
# ..                                                ...     ...        ...
# 59  "My son and I spent three days in Cumberland m...  0.9680   positive
# 60  "Scott and Gwen have it figured out! Provided ...  0.9545   positive
# 61  "Great location, easy walk to Main Street of C...  0.9638   positive
# 62  "Cute modern decor. I love the headboard in th...  0.9749   positive
# 63  "Anyone finding themselves up island from Vict...  0.9167   positive
# 64  "This 3 bedroom suite was everything you want ...  0.9712   positive
# 65  "Great place to stay with superb hosts. It pro...  0.9298   positive
# 66  "Gwen and Scott are lovely friendly people! Gw...  0.9824   positive
# 67  "We stayed here for 6 weeks while our new home...  0.8807   positive
# 68  "Margaret and I stayed for a couple of nights ...  0.9147   positive
# 69  "Stansbury\\'s is a warm, inviting place to st...  0.9880   positive
# 70  "Gwen and Scott have a clean, well run accommo...  0.9136   positive
# 71  "Couldn\\'t be a nicer location and the accomm...  0.9184   positive
# 72  "My partner stayed at Stansbury\\'s Guest Hous...  0.9885   positive
# 73  "It is a well run Guest House. Room was very c...  0.9335   positive
# 74  "We loved the decor of the suite and full amen...  0.9584   positive
# 75  "Stansbury\\'s is a perfect place in so many w...  0.9496   positive
# 76  "The owners are nice as is the property and ro...  0.8905   positive
# 77  "We enjoyed our stay at Stansbury\\'s. The roo...  0.8646   positive
# 78  "Stansbury\\'s Guest House was a perfect locat...  0.8519   positive
# 79  "A lovely welcoming place to stay. Spacious, v...  0.9745   positive
# 80  "We stayed in the 3 bedroom unit. It\\'s perfe...  0.9818   positive
# 81  "Chance meeting Gwen in July walking around Cu...  0.9570   positive
# 82  "I\\'ve stayed at Stansbury\\'s Guest House tw...  0.9501   positive
# 83  "We had a very nice stay. Scott and Gwen are v...  0.9376   positive
# 84  "We stayed here for the Woodstove Music festiv...  0.9881   positive
# 85  "Our suite had everything we needed. This is a...  0.9628   positive
# 86  "Thanks to Gwen for taking care of us (even br...  0.8550   positive
# 87  "We booked the three bedroom suite at Stansbur...  0.9734   positive
# 88  "This guest house is awesome. It is run person...  0.9895   positive
#
#                      Hotel_Name
# 28  Stansbury&#39;s Guest House
# 29  Stansbury&#39;s Guest House
# 30  Stansbury&#39;s Guest House
# 31  Stansbury&#39;s Guest House
# 32  Stansbury&#39;s Guest House
# 33  Stansbury&#39;s Guest House
# 34  Stansbury&#39;s Guest House
# 35  Stansbury&#39;s Guest House
# 36  Stansbury&#39;s Guest House
# 37  Stansbury&#39;s Guest House
# 38  Stansbury&#39;s Guest House
# 39  Stansbury&#39;s Guest House
# 40  Stansbury&#39;s Guest House
# 41  Stansbury&#39;s Guest House
# 42  Stansbury&#39;s Guest House
# 43  Stansbury&#39;s Guest House
# 44  Stansbury&#39;s Guest House
# 45  Stansbury&#39;s Guest House
# 46  Stansbury&#39;s Guest House
# 47  Stansbury&#39;s Guest House
# 48  Stansbury&#39;s Guest House
# 49  Stansbury&#39;s Guest House
# 50  Stansbury&#39;s Guest House
# 51  Stansbury&#39;s Guest House
# 52  Stansbury&#39;s Guest House
# 53  Stansbury&#39;s Guest House
# 54  Stansbury&#39;s Guest House
# 55  Stansbury&#39;s Guest House
# 56  Stansbury&#39;s Guest House
# 57  Stansbury&#39;s Guest House
# ..                          ...
# 59  Stansbury&#39;s Guest House
# 60  Stansbury&#39;s Guest House
# 61  Stansbury&#39;s Guest House
# 62  Stansbury&#39;s Guest House
# 63  Stansbury&#39;s Guest House
# 64  Stansbury&#39;s Guest House
# 65  Stansbury&#39;s Guest House
# 66  Stansbury&#39;s Guest House
# 67  Stansbury&#39;s Guest House
# 68  Stansbury&#39;s Guest House
# 69  Stansbury&#39;s Guest House
# 70  Stansbury&#39;s Guest House
# 71  Stansbury&#39;s Guest House
# 72  Stansbury&#39;s Guest House
# 73  Stansbury&#39;s Guest House
# 74  Stansbury&#39;s Guest House
# 75  Stansbury&#39;s Guest House
# 76  Stansbury&#39;s Guest House
# 77  Stansbury&#39;s Guest House
# 78  Stansbury&#39;s Guest House
# 79  Stansbury&#39;s Guest House
# 80  Stansbury&#39;s Guest House
# 81  Stansbury&#39;s Guest House
# 82  Stansbury&#39;s Guest House
# 83  Stansbury&#39;s Guest House
# 84  Stansbury&#39;s Guest House
# 85  Stansbury&#39;s Guest House
# 86  Stansbury&#39;s Guest House
# 87  Stansbury&#39;s Guest House
# 88  Stansbury&#39;s Guest House
#
# [61 rows x 4 columns]

# %% [markdown]
# #### (b) Rank hotels by
# ##### (i) Average Ground Truth Sentiment<br>(ii) Average Vader Compound Sentiment Score
# New Dataframe created with exp_index set as a binary column to suggest if the over all sentiment was positive (1) or negative (0)

# %%
exp = reviewDF['Experience']
exp_list = []
for e in exp:
    if e == 'positive':
        exp_list.append(1)
    else:
        exp_list.append(0)

# %%
exp_df = pd.DataFrame(exp_list,columns=['exp_index'])
reviewDF = pd.concat([reviewDF, exp_df], axis=1)

# %%
reviewDF.head()
# Out:
#                                            reviewCol   vader Experience  \
# 0  "I was looking for a place to sit and chill fo...  0.8442   positive
# 1  "I stayed at the Riding Fool Hostel whilst I w...  0.9965   positive
# 2  "My husband and I (both in our 50\\'s) stayed ...  0.9757   positive
# 3  "We were warmly  welcomed by Caitlin, the new ...  0.9766   positive
# 4  "Comfortable, cheap, and cosy accommodation wi...  0.4939   positive
#
#                Hotel_Name  exp_index
# 0  The Riding Fool Hostel          1
# 1  The Riding Fool Hostel          1
# 2  The Riding Fool Hostel          1
# 3  The Riding Fool Hostel          1
# 4  The Riding Fool Hostel          1

# %%
# Grouping by hotel name to understand the average review of each of the hotel and the number of reviews for them
# The "reviewCol" column is used to denote the number of reviews for each of the hotels
avg_rating = reviewDF.groupby('Hotel_Name').mean()
count = reviewDF.groupby('Hotel_Name').count()
print("The average vader rating grouped by hotel is: ",avg_rating.head())
print("The number of reviews grouped by hotels are: ", count.head())
# Out:
# The average vader rating grouped by hotel is:                             vader  exp_index
# Hotel_Name
# A&amp;J B&amp;B         0.973442   1.000000
# A-1 Alberni Inn         0.447724   0.523810
# Abbotsford Hotel        0.225563   0.359375
# Arbutus Grove Motel     0.897362   0.938144
# Artful Retreat B&amp;B  0.888300   1.000000
# The number of reviews grouped by hotels are:                          reviewCol  vader  Experience  exp_index
# Hotel_Name
# A&amp;J B&amp;B                19     19          19         19
# A-1 Alberni Inn                21     21          21         21
# Abbotsford Hotel               64     64          64         64
# Arbutus Grove Motel            97     97          97         97
# Artful Retreat B&amp;B          1      1           1          1

# %%
temp = count['reviewCol']
avg_rating = pd.concat([avg_rating, temp], axis=1)
avg_rating.head()
# Out:
#                            vader  exp_index  reviewCol
# Hotel_Name
# A&amp;J B&amp;B         0.973442   1.000000         19
# A-1 Alberni Inn         0.447724   0.523810         21
# Abbotsford Hotel        0.225563   0.359375         64
# Arbutus Grove Motel     0.897362   0.938144         97
# Artful Retreat B&amp;B  0.888300   1.000000          1

# %%
hotels_sorted = avg_rating.sort_values(by =["exp_index","reviewCol"],ascending=False) 
print("TOP 5 Ranking hotels by Average Ground Truth ")
top_5_GT = hotels_sorted.head(22)
top_5_GT.head()
# Out:
# TOP 5 Ranking hotels by Average Ground Truth
#                                    vader  exp_index  reviewCol
# Hotel_Name
# Stansbury&#39;s Guest House     0.948890        1.0         61
# Cedar Song B&amp;B and Cottage  0.942706        1.0         49
# Stamp Falls B &amp; B           0.938477        1.0         26
# Mozey-On-Inn                    0.913273        1.0         22
# Nimpo Lake Resort               0.940255        1.0         22

# %%
hotels_sorted_groundTruth = avg_rating.sort_values(by ="exp_index",ascending=True) 
print("BOTTOM 5 Ranking hotels by Average Ground Truth ")
hotels_sorted_groundTruth.head()
# Out:
# BOTTOM 5 Ranking hotels by Average Ground Truth
#                                       vader  exp_index  reviewCol
# Hotel_Name
# Howard Johnson Hotel Port Alberni  0.405518   0.243902         82
# Sorrento Inn                       0.241462   0.250000         16
# Bluebird Motel                     0.385882   0.272727         11
# Deerview Lodge &amp; Cabins        0.471357   0.285714          7
# Tyee Village Motel                 0.322247   0.333333         15

# %%
hotels_sorted_by_vader = avg_rating.sort_values(by ="vader",ascending=True) 
print("BOTTOM 5 Ranking hotels by Vader Compound Sentiment")
hotels_sorted_by_vader.head()
# Out:
# BOTTOM 5 Ranking hotels by Vader Compound Sentiment
#                            vader  exp_index  reviewCol
# Hotel_Name
# Jewel Bay Resort        0.205180   0.400000          5
# Abbotsford Hotel        0.225563   0.359375         64
# Sorrento Inn            0.241462   0.250000         16
# Tyee Village Motel      0.322247   0.333333         15
# China Creek Campground  0.335480   0.400000         10

# %%
hotels_sorted = avg_rating.sort_values(by =["vader"],ascending=False) 
print("TOP 5 Ranking hotels by Vader")
hotels_sorted.head()
# Out:
# TOP 5 Ranking hotels by Vader
#                                          vader  exp_index  reviewCol
# Hotel_Name
# A&amp;J B&amp;B                       0.973442        1.0         19
# Retreat Wilderness Inn                0.972945        1.0         11
# Mt H&#39;Kusam View Lodge             0.968571        1.0          7
# San Jose River Ranch Cariboo B&amp;B  0.967820        1.0          5
# Char&#39;s Landing Guesthouse         0.967400        1.0          2

# %% [markdown]
# #### Comparison of Top 5 hotels based on average ratings vs average vader scores:
# <b>Top 5 according to average ground truth:</b> Stansbury's Guest House, Cedar Song B&B and Cottage, Stamp Falls B, Mozey-On-Inn, Nimpo Lake Resort
# <br> <b>Top 5 according to average vader:</b> A&J B&B, Retreat Wilderness Inn, Mt H'Kusam View Lodge, San Jose River Ranch Cariboo B&B, Char's Landing Guesthouse
# <br>The top five hotels for the average vader score and the average ground truth scores do not match as there are 22 hotels that have a perfect average ground truth rating (100% of the people visiting had positive experiences). The degree to which they had a positive experience is not captures by the binary rating. However, it is captured by the vader scores. The top five hotels based on average ground truth was first filtered as having all positive (1.0) and then filtered by the number of reviews for that hotel. This is why the top five from vader scores do not apprear in the top five of the ground truth average.

# %% [markdown]
# ### Q2. Frequency Analysis
# #### (a) Using term frequency of the words for :
# <b>(i) positive reviews and <br>
#     (ii) negative with ground truth sentiment to rank the top-50 most frequent non-stopwords in the review collection.

# %%
def freq_analysis(reviews, k):
    stop = set(stopwords.words('english'))
    counter = Counter()
    for review in reviews:
            counter.update([word.lower() 
                            for word 
                            in re.findall(r'\w+', review) 
                            if word.lower() not in stop and len(word) > 2])
    topk = counter.most_common(k)  
    return topk

# %%
print("Top 50 words used in the positive reviews")
# Extracting only the positivly reviewed hotels and their associated text to study the most frequently used words
pos = reviews_df[reviews_df["Experience"]=='positive']['Review text']
result_pos = freq_analysis(pos,50)
l_pos = len(pos)-1
result_pos
# Out:
# Top 50 words used in the positive reviews
# [('room', 2391),
#  ('great', 1980),
#  ('stay', 1830),
#  ('clean', 1586),
#  ('hotel', 1578),
#  ('staff', 1538),
#  ('beach', 1265),
#  ('stayed', 1181),
#  ('good', 1163),
#  ('well', 1146),
#  ('would', 1135),
#  ('nice', 1124),
#  ('friendly', 1113),
#  ('comfortable', 1069),
#  ('one', 1034),
#  ('place', 1023),
#  ('rooms', 957),
#  ('breakfast', 904),
#  ('resort', 844),
#  ('time', 763),
#  ('restaurant', 744),
#  ('area', 719),
#  ('night', 683),
#  ('back', 678),
#  ('pool', 667),
#  ('helpful', 646),
#  ('view', 643),
#  ('service', 623),
#  ('location', 598),
#  ('also', 576),
#  ('family', 576),
#  ('nthe', 571),
#  ('bed', 564),
#  ('two', 559),
#  ('food', 545),
#  ('amp', 532),
#  ('recommend', 520),
#  ('like', 519),
#  ('beautiful', 518),
#  ('day', 516),
#  ('really', 505),
#  ('quiet', 503),
#  ('excellent', 497),
#  ('get', 496),
#  ('best', 493),
#  ('front', 493),
#  ('everything', 491),
#  ('kitchen', 478),
#  ('beds', 474),
#  ('could', 461)]

# %%
pos_df = pd.DataFrame({'Index':pos.index, 'Review':pos.values})
pos_df[3354:3358]
pos_rev_df= pos_df['Review']
pos_rev_df.head()
# Out:
# 0    "I was looking for a place to sit and chill fo...
# 1    "I stayed at the Riding Fool Hostel whilst I w...
# 2    "My husband and I (both in our 50\\'s) stayed ...
# 3    "We were warmly  welcomed by Caitlin, the new ...
# 4    "Comfortable, cheap, and cosy accommodation wi...
# Name: Review, dtype: object

# %%
print("Top 50 words used in the negative reviews")
neg = reviews_df[reviews_df["Experience"]=='negative']['Review text']
result_neg = freq_analysis(neg,50)
result_neg
#len(neg)
# Out:
# Top 50 words used in the negative reviews
# [('room', 1054),
#  ('hotel', 565),
#  ('would', 405),
#  ('stay', 368),
#  ('one', 318),
#  ('night', 302),
#  ('quot', 302),
#  ('clean', 288),
#  ('good', 277),
#  ('place', 275),
#  ('rooms', 265),
#  ('staff', 250),
#  ('nice', 239),
#  ('breakfast', 225),
#  ('stayed', 217),
#  ('time', 211),
#  ('get', 201),
#  ('desk', 196),
#  ('bed', 189),
#  ('nthe', 185),
#  ('front', 184),
#  ('like', 176),
#  ('could', 173),
#  ('great', 164),
#  ('even', 157),
#  ('bathroom', 154),
#  ('back', 153),
#  ('well', 148),
#  ('restaurant', 146),
#  ('check', 145),
#  ('small', 143),
#  ('door', 142),
#  ('beach', 142),
#  ('day', 141),
#  ('resort', 141),
#  ('service', 141),
#  ('next', 140),
#  ('also', 138),
#  ('friendly', 132),
#  ('motel', 132),
#  ('two', 131),
#  ('got', 126),
#  ('floor', 125),
#  ('told', 124),
#  ('really', 122),
#  ('little', 122),
#  ('pool', 120),
#  ('much', 119),
#  ('view', 118),
#  ('said', 115)]

# %%
words_pos = [i[0] for i in result_pos]
words_neg = [i[0] for i in result_neg]

# %%
#Some words are repeating themselves and it is useful to see which words were common for both lists
s = set(words_neg)
common_words = [x for x in words_pos if x in s]
common_words
# Out:
# ['room',
#  'great',
#  'stay',
#  'clean',
#  'hotel',
#  'staff',
#  'beach',
#  'stayed',
#  'good',
#  'well',
#  'would',
#  'nice',
#  'friendly',
#  'one',
#  'place',
#  'rooms',
#  'breakfast',
#  'resort',
#  'time',
#  'restaurant',
#  'night',
#  'back',
#  'pool',
#  'view',
#  'service',
#  'also',
#  'nthe',
#  'bed',
#  'two',
#  'like',
#  'day',
#  'really',
#  'get',
#  'front',
#  'could']

# %%
count = 0 
for review in neg:
    if 'great' in review:
        count += 1
        print (count,"Review number",review)
        print("")
# Out:
# 1 Review number "My biggest complaint with the Riding Fool is the lack of door closure on the dorm room doors. Resulting in the door never properly closing, or banging shut, both creating more noise in the room than necessary. Bunks are stable so you don\\'t really hear the top one going to bed which is great. Lockers are a good size. Kitchen is well equipped.
#
# 2 Review number "Stayed in Room 7 recently. Noise from the staff quarters immediately below made sleeping difficult. The whole establishment is spacious, airy, super-clean, and the facilities are outstanding. And Cumberland is a great place to relax. But the sound-proofing in the hostel is terrible. Take your ear plugs.
#
# There were multiple words that were present in both the negative review and the positive review. While most of these words were neutral nouns, the adjectives attached to the words would be the emotion carrying word (the context set the tone of the word). However, words such as "great" and "clean" appear in the negative review, this is because one part of the review is positive in nature, however the core of the review is still negative. This is evident by vitual inspection from the previous cell, where certain aspects of the hotel was "great", while other parts were bad and therefore catagorized as a negative ground truth.

# %%
#Analyzing the context by implmenting Part-of-speech tagging of full review sentences
tagger = PerceptronTagger()
taggedToks=[]
pos_tag = tagger.tag
for i in range(l_pos):
    t=i+1
    #print(pos_df[i:t])
    taggedToks.append(pos_tag(re.findall(r'\w+', pos_rev_df[i])))

# %%
taggedToks[:10]
# Out:
# [[('I', 'PRP'),
#   ('was', 'VBD'),
#   ('looking', 'VBG'),
#   ('for', 'IN'),
#   ('a', 'DT'),
#   ('place', 'NN'),
#   ('to', 'TO'),
#   ('sit', 'VB'),
#   ('and', 'CC'),
#   ('chill', 'VB'),
#   ('for', 'IN'),
#   ('a', 'DT'),
#   ('while', 'NN'),
#   ('and', 'CC'),
#   ('I', 'PRP'),
#   ('found', 'VBD'),
#   ('it', 'PRP'),
#   ('in', 'IN'),
#   ('the', 'DT'),
#   ('Riding', 'NNP'),
#   ('Fool', 'NNP'),
#   ('Hostel', 'NNP'),
#   ('in', 'IN'),
#   ('Cumberland', 'NNP'),
#   ('Great', 'NNP'),
#   ('kitchen', 'NN'),
#   ('and', 'CC'),
#   ('common', 'JJ'),
#   ('area', 'NN'),
#   ('comfy', 'NN'),
#   ('beds', 'NNS'),
#   ('and', 'CC'),
#   ('nice', 'JJ'),
#   ('folks', 'NNS'),
#   ('What', 'WP'),
#   ('more', 'JJR'),
#   ('could', 'MD'),
#   ('you', 'PRP'),
#   ('ask', 'VB'),
#   ('for', 'IN'),
#   ('Oh', 'NNP'),
#   ('there', 'EX'),
#   ('s', 'VBZ'),
#   ('the', 'DT'),
#   ('nearby', 'JJ'),
#   ('mountain', 'NN'),
#   ('biking', 'NN'),
#   ('trails', 'VBZ'),
#   ('rivers', 'NNS'),
#   ('lakes', 'VBZ'),
#   ('not', 'RB'),
#   ('to', 'TO'),
#   ('mention', 'VB'),
#   ('the', 'DT'),
#   ('big', 'JJ'),
#   ('mountain', 'NN'),
#   ('just', 'RB'),
#   ('a', 'DT'),
#   ('short', 'JJ'),
#   ('distance', 'NN'),
#   ('away', 'RB'),
#   ('And', 'CC'),
#   ('while', 'IN'),
#   ('the', 'DT'),
#   ('town', 'NN'),
#   ('of', 'IN'),
#   ('Cumberland', 'NNP'),
#   ('is', 'VBZ'),
#   ('small', 'JJ'),
#   ('it', 'PRP'),
#   ('s', 'JJ'),
#   ('cute', 'NN'),
#   ('and', 'CC'),
#   ('cozy', 'NN'),
#   ('and', 'CC'),
#   ('there', 'EX'),
#   ('s', 'VB'),
#   ('a', 'DT'),
#   ('surprising', 'JJ'),
#   ('amount', 'NN'),
#   ('of', 'IN'),
#   ('stuff', 'NN'),
#   ('to', 'TO'),
#   ('do', 'VB')],
#  [('I', 'PRP'),
#   ('stayed', 'VBD'),
#   ('at', 'IN'),
#   ('the', 'DT'),
#   ('Riding', 'NNP'),
#   ('Fool', 'NNP'),
#   ('Hostel', 'NNP'),
#   ('whilst', 'NN'),
#   ('I', 'PRP'),
#   ('was', 'VBD'),
#   ('snowboarding', 'VBG'),
#   ('at', 'IN'),
#   ('Mount', 'NNP'),
#   ('Washington', 'NNP'),
#   ('Alpine', 'NNP'),
#   ('Resort', 'NNP'),
#   ('It', 'PRP'),
#   ('was', 'VBD'),
#   ('recommended', 'VBN'),
#   ('to', 'TO'),
#   ('me', 'PRP'),
#   ('by', 'IN'),
#   ('a', 'DT'),
#   ('friend', 'NN'),
#   ('who', 'WP'),
#   ('had', 'VBD'),
#   ('stayed', 'VBN'),
#   ('there', 'RB'),
#   ('previously', 'RB'),
#   ('The', 'DT'),
#   ('hostel', 'NN'),
#   ('is', 'VBZ'),
#   ('located', 'VBN'),
#   ('in', 'IN'),
#   ('a', 'DT'),
#   ('quaint', 'JJ'),
#   ('little', 'JJ'),
#   ('town', 'NN'),
#   ('called', 'VBN'),
#   ('Cumberland', 'NNP'),
#   ('which', 'WDT'),
#   ('is', 'VBZ'),
#   ('about', 'IN'),
#   ('10', 'CD'),
#   ('minute', 'JJ'),
#   ('drive', 'NN'),
#   ('from', 'IN'),
#   ('Courtenay', 'NNP'),
#   ('on', 'IN'),
#   ('Vancouver', 'NNP'),
#   ('Island', 'NNP'),
#   ('There', 'EX'),
#   ('is', 'VBZ'),
#   ('a', 'DT'),
#   ('bunch', 'NN'),
#   ('of', 'IN'),
#   ('info', 'NN'),
#   ('about', 'IN'),
#   ('the', 'DT'),
#   ('actual', 'JJ'),
#   ('hostel', 'NN'),
#   ('on', 'IN'),
#   ('the', 'DT'),
#   ('web', 'NN'),
#   ('site', 'NN'),
#   ('if', 'IN'),
#   ('you', 'PRP'),
#   ('want', 'VBP'),
#   ('more', 'JJR'),
#   ('information', 'NN'),
#   ('about', 'IN'),
#   ('the', 'DT'),
#   ('actual', 'JJ'),
#   ('amenities', 'NNS'),
#   ('etc', 'VBP'),
#   ('so', 'RB'),
#   ('I', 'PRP'),
#   ('won', 'VBD'),
#   ('t', 'JJ'),
#   ('duplicate', 'NN'),
#   ('that', 'WDT'),
#   ('info', 'NN'),
#   ('here', 'RB'),
#   ('n', 'VBZ'),
#   ('nThe', 'JJ'),
#   ('hostel', 'NN'),
#   ('is', 'VBZ'),
#   ('run', 'VBN'),
#   ('by', 'IN'),
#   ('Jeremy', 'NNP'),
#   ('and', 'CC'),
#   ('is', 'VBZ'),
#   ('above', 'JJ'),
#   ('Dodge', 'NNP'),
#   ('City', 'NNP'),
#   ('Cycles', 'NNP'),
#   ('which', 'WDT'),
#   ('is', 'VBZ'),
#   ('a', 'DT'),
#   ('bicycle', 'NN'),
#   ('shop', 'NN'),
#   ('located', 'VBN'),
#   ('in', 'IN'),
#   ('the', 'DT'),
#   ('main', 'JJ'),
#   ('street', 'NN'),
#   ('The', 'DT'),
#   ('first', 'JJ'),
#   ('thing', 'NN'),
#   ('that', 'WDT'),
#   ('really', 'RB'),
#   ('struck', 'VB'),
#   ('me', 'PRP'),
#   ('is', 'VBZ'),
#   ('the', 'DT'),
#   ('host', 'NN'),
#   ('Jeremy', 'NNP'),
#   ('he', 'PRP'),
#   ('s', 'VBD'),
#   ('a', 'DT'),
#   ('fantastic', 'JJ'),
#   ('person', 'NN'),
#   ('who', 'WP'),
#   ('takes', 'VBZ'),
#   ('an', 'DT'),
#   ('interest', 'NN'),
#   ('in', 'IN'),
#   ('the', 'DT'),
#   ('guests', 'NNS'),
#   ('and', 'CC'),
#   ('really', 'RB'),
#   ('seems', 'VBZ'),
#   ('to', 'TO'),
#   ('care', 'VB'),
#   ('about', 'IN'),
#   ('them', 'PRP'),
#   ('and', 'CC'),
#   ('goes', 'VBZ'),
#   ('out', 'IN'),
#   ('of', 'IN'),
#   ('his', 'PRP$'),
#   ('way', 'NN'),
#   ('to', 'TO'),
#   ('ensure', 'VB'),
#   ('that', 'IN'),
#   ('they', 'PRP'),
#   ('have', 'VBP'),
#   ('an', 'DT'),
#   ('enjoyable', 'JJ'),
#   ('stay', 'NN'),
#   ('He', 'PRP'),
#   ('s', 'VBZ'),
#   ('also', 'RB'),
#   ('very', 'RB'),
#   ('knowledgeable', 'JJ'),
#   ('and', 'CC'),
#   ('is', 'VBZ'),
#   ('able', 'JJ'),
#   ('to', 'TO'),
#   ('provide', 'VB'),
#   ('lots', 'NNS'),
#   ('of', 'IN'),
#   ('tips', 'NNS'),
#   ('about', 'IN'),
#   ('the', 'DT'),
#   ('area', 'NN'),
#   ('and', 'CC'),
#   ('suggest', 'VBP'),
#   ('things', 'NNS'),
#   ('you', 'PRP'),
#   ('can', 'MD'),
#   ('do', 'VB'),
#   ('He', 'PRP'),
#   ('s', 'VB'),
#   ('a', 'DT'),
#   ('mad', 'JJ'),
#   ('keen', 'NN'),
#   ('mountain', 'NN'),
#   ('biker', 'NN'),
#   ('as', 'IN'),
#   ('well', 'RB'),
#   ('for', 'IN'),
#   ('all', 'DT'),
#   ('you', 'PRP'),
#   ('MTB', 'NNP'),
#   ('ers', 'VBZ'),
#   ('out', 'RP'),
#   ('there', 'RB'),
#   ('n', 'RB'),
#   ('nThe', 'IN'),
#   ('other', 'JJ'),
#   ('thing', 'NN'),
#   ('that', 'IN'),
#   ('you', 'PRP'),
#   ('ll', 'VBP'),
#   ('notice', 'RB'),
#   ('about', 'IN'),
#   ('the', 'DT'),
#   ('hostel', 'NN'),
#   ('is', 'VBZ'),
#   ('that', 'IN'),
#   ('it', 'PRP'),
#   ('is', 'VBZ'),
#   ('very', 'RB'),
#   ('well', 'RB'),
#   ('maintained', 'VBN'),
#   ('and', 'CC'),
#   ('clean', 'JJ'),
#   ('and', 'CC'),
#   ('there', 'EX'),
#   ('are', 'VBP'),
#   ('enough', 'JJ'),
#   ('bathrooms', 'NNS'),
#   ('available', 'JJ'),
#   ('for', 'IN'),
#   ('the', 'DT'),
#   ('number', 'NN'),
#   ('of', 'IN'),
#   ('guests', 'NNS'),
#   ('that', 'WDT'),
#   ('can', 'MD'),
#   ('stay', 'VB'),
#   ('in', 'IN'),
#   ('the', 'DT'),
#   ('hostel', 'NN'),
#   ('n', 'IN'),
#   ('nThe', 'JJ'),
#   ('wireless', 'JJ'),
#   ('internet', 'NN'),
#   ('access', 'NN'),
#   ('is', 'VBZ'),
#   ('free', 'JJ'),
#   ('and', 'CC'),
#   ('is', 'VBZ'),
#   ('very', 'RB'),
#   ('reliable', 'JJ'),
#   ('and', 'CC'),
#   ('fast', 'JJ'),
#   ('and', 'CC'),
#   ('there', 'EX'),
#   ('is', 'VBZ'),
#   ('a', 'DT'),
#   ('common', 'JJ'),
#   ('computer', 'NN'),
#   ('that', 'IN'),
#   ('you', 'PRP'),
#   ('can', 'MD'),
#   ('use', 'VB'),
#   ('if', 'IN'),
#   ('you', 'PRP'),
#   ('don', 'VBP'),
#   ('t', 'NNS'),
#   ('have', 'VBP'),
#   ('a', 'DT'),
#   ('laptop', 'NN'),
#   ('There', 'EX'),
#   ('are', 'VBP'),
#   ('also', 'RB'),
#   ('cruiser', 'JJ'),
#   ('bicycles', 'NNS'),
#   ('available', 'JJ'),
#   ('which', 'WDT'),
#   ('you', 'PRP'),
#   ('can', 'MD'),
#   ('take', 'VB'),
#   ('for', 'IN'),
#   ('a', 'DT'),
#   ('ride', 'NN'),
#   ('although', 'IN'),
#   ('I', 'PRP'),
#   ('didn', 'VBP'),
#   ('t', 'JJ'),
#   ('do', 'VBP'),
#   ('that', 'DT'),
#   ('given', 'VBN'),
#   ('that', 'IN'),
#   ('it', 'PRP'),
#   ('was', 'VBD'),
#   ('winter', 'VBG'),
#   ('The', 'DT'),
#   ('common', 'JJ'),
#   ('kitchen', 'NN'),
#   ('is', 'VBZ'),
#   ('well', 'RB'),
#   ('equipped', 'VBN'),
#   ('and', 'CC'),
#   ('there', 'EX'),
#   ('is', 'VBZ'),
#   ('a', 'DT'),
#   ('good', 'JJ'),
#   ('system', 'NN'),
#   ('for', 'IN'),
#   ('everyone', 'NN'),
#   ('to', 'TO'),
#   ('keep', 'VB'),
#   ('their', 'PRP$'),
#   ('food', 'NN'),
#   ('clearly', 'RB'),
#   ('identified', 'VBD'),
#   ('The', 'DT'),
#   ('common', 'JJ'),
#   ('room', 'NN'),
#   ('has', 'VBZ'),
#   ('a', 'DT'),
#   ('pool', 'NN'),
#   ('table', 'NN'),
#   ('and', 'CC'),
#   ('Jeremy', 'NNP'),
#   ('ran', 'VBD'),
#   ('a', 'DT'),
#   ('Pizza', 'NNP'),
#   ('and', 'CC'),
#   ('Video', 'NNP'),
#   ('night', 'NN'),
#   ('whilst', 'NN'),
#   ('I', 'PRP'),
#   ('was', 'VBD'),
#   ('there', 'EX'),
#   ('which', 'WDT'),
#   ('went', 'VBD'),
#   ('down', 'RB'),
#   ('extremely', 'RB'),
#   ('well', 'RB'),
#   ('with', 'IN'),
#   ('everyone', 'NN'),
#   ('n', 'JJ'),
#   ('nI', 'NN'),
#   ('was', 'VBD'),
#   ('staying', 'VBG'),
#   ('there', 'RB'),
#   ('during', 'IN'),
#   ('the', 'DT'),
#   ('winter', 'NN'),
#   ('and', 'CC'),
#   ('so', 'RB'),
#   ('a', 'DT'),
#   ('good', 'JJ'),
#   ('number', 'NN'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('people', 'NNS'),
#   ('staying', 'VBG'),
#   ('at', 'IN'),
#   ('the', 'DT'),
#   ('hostel', 'NN'),
#   ('were', 'VBD'),
#   ('long', 'JJ'),
#   ('term', 'NN'),
#   ('guests', 'NNS'),
#   ('who', 'WP'),
#   ('were', 'VBD'),
#   ('working', 'VBG'),
#   ('up', 'RP'),
#   ('at', 'IN'),
#   ('Mount', 'NNP'),
#   ('Washington', 'NNP'),
#   ('Alpine', 'NNP'),
#   ('Resort', 'NNP'),
#   ('for', 'IN'),
#   ('the', 'DT'),
#   ('season', 'NN'),
#   ('I', 'PRP'),
#   ('found', 'VBD'),
#   ('the', 'DT'),
#   ('long', 'JJ'),
#   ('term', 'NN'),
#   ('residents', 'NNS'),
#   ('to', 'TO'),
#   ('be', 'VB'),
#   ('great', 'JJ'),
#   ('and', 'CC'),
#   ('really', 'RB'),
#   ('friendly', 'JJ'),
#   ('Unlike', 'IN'),
#   ('some', 'DT'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('hostels', 'NNS'),
#   ('I', 'PRP'),
#   ('have', 'VBP'),
#   ('stayed', 'VBN'),
#   ('at', 'IN'),
#   ('there', 'EX'),
#   ('was', 'VBD'),
#   ('very', 'RB'),
#   ('little', 'JJ'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('late', 'JJ'),
#   ('night', 'NN'),
#   ('antics', 'NNS'),
#   ('or', 'CC'),
#   ('noise', 'NN'),
#   ('that', 'IN'),
#   ('you', 'PRP'),
#   ('typically', 'RB'),
#   ('associate', 'VBP'),
#   ('with', 'IN'),
#   ('hostels', 'NNS'),
#   ('n', 'JJ'),
#   ('nIn', 'JJ'),
#   ('terms', 'NNS'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('actual', 'JJ'),
#   ('town', 'NN'),
#   ('of', 'IN'),
#   ('Cumberland', 'NNP'),
#   ('it', 'PRP'),
#   ('s', 'VBD'),
#   ('a', 'DT'),
#   ('quiet', 'JJ'),
#   ('place', 'NN'),
#   ('but', 'CC'),
#   ('the', 'DT'),
#   ('local', 'JJ'),
#   ('Waverley', 'NNP'),
#   ('Hotel', 'NNP'),
#   ('is', 'VBZ'),
#   ('pretty', 'RB'),
#   ('good', 'JJ'),
#   ('and', 'CC'),
#   ('has', 'VBZ'),
#   ('a', 'DT'),
#   ('half', 'JJ'),
#   ('price', 'NN'),
#   ('burger', 'NN'),
#   ('night', 'NN'),
#   ('on', 'IN'),
#   ('Tuesdays', 'NNP'),
#   ('which', 'WDT'),
#   ('is', 'VBZ'),
#   ('great', 'JJ'),
#   ('value', 'NN'),
#   ('for', 'IN'),
#   ('money', 'NN'),
#   ('and', 'CC'),
#   ('the', 'DT'),
#   ('hotel', 'NN'),
#   ('also', 'RB'),
#   ('gets', 'VBZ'),
#   ('some', 'DT'),
#   ('live', 'JJ'),
#   ('bands', 'NNS'),
#   ('in', 'IN'),
#   ('The', 'DT'),
#   ('Indian', 'JJ'),
#   ('restaurant', 'NN'),
#   ('nearby', 'NN'),
#   ('is', 'VBZ'),
#   ('also', 'RB'),
#   ('very', 'RB'),
#   ('good', 'JJ'),
#   ('There', 'EX'),
#   ('are', 'VBP'),
#   ('places', 'NNS'),
#   ('in', 'IN'),
#   ('the', 'DT'),
#   ('town', 'NN'),
#   ('to', 'TO'),
#   ('buy', 'VB'),
#   ('basic', 'JJ'),
#   ('groceries', 'NNS'),
#   ('but', 'CC'),
#   ('if', 'IN'),
#   ('you', 'PRP'),
#   ('want', 'VBP'),
#   ('a', 'DT'),
#   ('good', 'JJ'),
#   ('selection', 'NN'),
#   ('you', 'PRP'),
#   ('ll', 'VBP'),
#   ('need', 'VB'),
#   ('to', 'TO'),
#   ('go', 'VB'),
#   ('shopping', 'NN'),
#   ('in', 'IN'),
#   ('Courtenay', 'NNP'),
#   ('n', 'FW'),
#   ('nIt', 'NN'),
#   ('was', 'VBD'),
#   ('a', 'DT'),
#   ('great', 'JJ'),
#   ('place', 'NN'),
#   ('to', 'TO'),
#   ('stay', 'VB'),
#   ('and', 'CC'),
#   ('everyone', 'NN'),
#   ('was', 'VBD'),
#   ('very', 'RB'),
#   ('welcoming', 'JJ'),
#   ('I', 'PRP'),
#   ('would', 'MD'),
#   ('highly', 'RB'),
#   ('recommend', 'VB'),
#   ('that', 'IN'),
#   ('you', 'PRP'),
#   ('check', 'VB'),
#   ('it', 'PRP'),
#   ('out', 'RP')],
#  [('My', 'PRP$'),
#   ('husband', 'NN'),
#   ('and', 'CC'),
#   ('I', 'PRP'),
#   ('both', 'DT'),
#   ('in', 'IN'),
#   ('our', 'PRP$'),
#   ('50', 'CD'),
#   ('s', 'NN'),
#   ('stayed', 'VBN'),
#   ('here', 'RB'),
#   ('for', 'IN'),
#   ('a', 'DT'),
#   ('few', 'JJ'),
#   ('nights', 'NNS'),
#   ('in', 'IN'),
#   ('July', 'NNP'),
#   ('2012', 'CD'),
#   ('and', 'CC'),
#   ('really', 'RB'),
#   ('loved', 'VBD'),
#   ('it', 'PRP'),
#   ('The', 'DT'),
#   ('folks', 'NNS'),
#   ('who', 'WP'),
#   ('checked', 'VBD'),
#   ('us', 'PRP'),
#   ('in', 'IN'),
#   ('we', 'PRP'),
#   ('re', 'VBP'),
#   ('sweet', 'JJ'),
#   ('and', 'CC'),
#   ('helpful', 'JJ'),
#   ('The', 'DT'),
#   ('place', 'NN'),
#   ('is', 'VBZ'),
#   ('huge', 'JJ'),
#   ('the', 'DT'),
#   ('kitchen', 'NN'),
#   ('well', 'RB'),
#   ('stocked', 'VBN'),
#   ('there', 'EX'),
#   ('is', 'VBZ'),
#   ('even', 'RB'),
#   ('a', 'DT'),
#   ('pool', 'NN'),
#   ('table', 'NN'),
#   ('We', 'PRP'),
#   ('were', 'VBD'),
#   ('able', 'JJ'),
#   ('to', 'TO'),
#   ('rent', 'VB'),
#   ('a', 'DT'),
#   ('private', 'JJ'),
#   ('room', 'NN'),
#   ('and', 'CC'),
#   ('were', 'VBD'),
#   ('very', 'RB'),
#   ('comfortable', 'JJ'),
#   ('It', 'PRP'),
#   ('is', 'VBZ'),
#   ('a', 'DT'),
#   ('tiny', 'JJ'),
#   ('town', 'NN'),
#   ('but', 'CC'),
#   ('has', 'VBZ'),
#   ('some', 'DT'),
#   ('nice', 'JJ'),
#   ('shops', 'NNS'),
#   ('and', 'CC'),
#   ('a', 'DT'),
#   ('couple', 'JJ'),
#   ('places', 'NNS'),
#   ('to', 'TO'),
#   ('eat', 'VB'),
#   ('If', 'IN'),
#   ('you', 'PRP'),
#   ('are', 'VBP'),
#   ('into', 'IN'),
#   ('mountain', 'NN'),
#   ('biking', 'NN'),
#   ('this', 'DT'),
#   ('is', 'VBZ'),
#   ('a', 'DT'),
#   ('great', 'JJ'),
#   ('place', 'NN'),
#   ('to', 'TO'),
#   ('stay', 'VB'),
#   ('as', 'IN'),
#   ('there', 'EX'),
#   ('is', 'VBZ'),
#   ('world', 'NN'),
#   ('class', 'NN'),
#   ('mountain', 'NN'),
#   ('biking', 'NN'),
#   ('from', 'IN'),
#   ('the', 'DT'),
#   ('door', 'JJ'),
#   ('step', 'NN'),
#   ('seriously', 'RB'),
#   ('Great', 'NNP'),
#   ('place', 'NN')],
#  [('We', 'PRP'),
#   ('were', 'VBD'),
#   ('warmly', 'RB'),
#   ('welcomed', 'VBN'),
#   ('by', 'IN'),
#   ('Caitlin', 'NNP'),
#   ('the', 'DT'),
#   ('new', 'JJ'),
#   ('employee', 'NN'),
#   ('from', 'IN'),
#   ('Australia', 'NNP'),
#   ('and', 'CC'),
#   ('she', 'PRP'),
#   ('was', 'VBD'),
#   ('very', 'RB'),
#   ('accommodating', 'VBG'),
#   ('in', 'IN'),
#   ('showing', 'VBG'),
#   ('us', 'PRP'),
#   ('around', 'IN'),
#   ('We', 'PRP'),
#   ('are', 'VBP'),
#   ('in', 'IN'),
#   ('our', 'PRP$'),
#   ('60', 'CD'),
#   ('s', 'NN'),
#   ('and', 'CC'),
#   ('had', 'VBD'),
#   ('a', 'DT'),
#   ('private', 'JJ'),
#   ('room', 'NN'),
#   ('The', 'DT'),
#   ('room', 'NN'),
#   ('was', 'VBD'),
#   ('clean', 'JJ'),
#   ('and', 'CC'),
#   ('comfortable', 'JJ'),
#   ('and', 'CC'),
#   ('we', 'PRP'),
#   ('had', 'VBD'),
#   ('a', 'DT'),
#   ('great', 'JJ'),
#   ('sleep', 'NN'),
#   ('There', 'EX'),
#   ('were', 'VBD'),
#   ('only', 'RB'),
#   ('4', 'CD'),
#   ('other', 'JJ'),
#   ('guests', 'NNS'),
#   ('so', 'RB'),
#   ('basically', 'RB'),
#   ('we', 'PRP'),
#   ('had', 'VBD'),
#   ('our', 'PRP$'),
#   ('own', 'JJ'),
#   ('bathroom', 'NN'),
#   ('and', 'CC'),
#   ('it', 'PRP'),
#   ('was', 'VBD'),
#   ('very', 'RB'),
#   ('clean', 'JJ'),
#   ('sink', 'NN'),
#   ('toilet', 'NN'),
#   ('and', 'CC'),
#   ('bathtub', 'NN'),
#   ('shower', 'NN'),
#   ('We', 'PRP'),
#   ('rented', 'VBD'),
#   ('towels', 'NNS'),
#   ('for', 'IN'),
#   ('2', 'CD'),
#   ('00', 'CD'),
#   ('each', 'DT'),
#   ('n', 'NN'),
#   ('The', 'DT'),
#   ('kitchen', 'NN'),
#   ('was', 'VBD'),
#   ('large', 'JJ'),
#   ('and', 'CC'),
#   ('well', 'RB'),
#   ('equipped', 'VBN'),
#   ('with', 'IN'),
#   ('dishes', 'NNS'),
#   ('and', 'CC'),
#   ('utensils', 'VBZ'),
#   ('The', 'DT'),
#   ('common', 'JJ'),
#   ('room', 'NN'),
#   ('was', 'VBD'),
#   ('very', 'RB'),
#   ('large', 'JJ'),
#   ('with', 'IN'),
#   ('lots', 'NNS'),
#   ('of', 'IN'),
#   ('seating', 'NN'),
#   ('and', 'CC'),
#   ('a', 'DT'),
#   ('pool', 'NN'),
#   ('table', 'NN'),
#   ('a', 'DT'),
#   ('great', 'JJ'),
#   ('place', 'NN'),
#   ('to', 'TO'),
#   ('meet', 'VB'),
#   ('and', 'CC'),
#   ('chat', 'VB'),
#   ('with', 'IN'),
#   ('other', 'JJ'),
#   ('travelers', 'NNS'),
#   ('nThis', 'VBP'),
#   ('hostel', 'NN'),
#   ('reminds', 'VBZ'),
#   ('us', 'PRP'),
#   ('of', 'IN'),
#   ('hostels', 'NNS'),
#   ('in', 'IN'),
#   ('Australia', 'NNP'),
#   ('and', 'CC'),
#   ('New', 'NNP'),
#   ('Zealand', 'NNP'),
#   ('and', 'CC'),
#   ('we', 'PRP'),
#   ('heartily', 'RB'),
#   ('recommend', 'VBP'),
#   ('it', 'PRP')],
#  [('Comfortable', 'JJ'),
#   ('cheap', 'NNS'),
#   ('and', 'CC'),
#   ('cosy', 'JJ'),
#   ('accommodation', 'NN'),
#   ('with', 'IN'),
#   ('bike', 'NN'),
#   ('storage', 'NN'),
#   ('and', 'CC'),
#   ('tools', 'NNS'),
#   ('for', 'IN'),
#   ('mountainbikers', 'NNS'),
#   ('n', 'VBP'),
#   ('nThe', 'JJ'),
#   ('hostel', 'NN'),
#   ('has', 'VBZ'),
#   ('a', 'DT'),
#   ('massive', 'JJ'),
#   ('kitchen', 'NN'),
#   ('and', 'CC'),
#   ('living', 'NN'),
#   ('room', 'NN'),
#   ('area', 'NN'),
#   ('for', 'IN'),
#   ('post', 'NN'),
#   ('ride', 'NN'),
#   ('chilling', 'VBG'),
#   ('assuming', 'VBG'),
#   ('you', 'PRP'),
#   ('re', 'VBP'),
#   ('not', 'RB'),
#   ('heading', 'VBG'),
#   ('to', 'TO'),
#   ('the', 'DT'),
#   ('Waverley', 'NNP'),
#   ('for', 'IN'),
#   ('a', 'DT'),
#   ('cheeky', 'JJ'),
#   ('beer', 'NN'),
#   ('or', 'CC'),
#   ('two', 'CD'),
#   ('n', 'JJ'),
#   ('nIn', 'JJ'),
#   ('case', 'NN'),
#   ('you', 'PRP'),
#   ('didn', 'VBP'),
#   ('t', 'JJ'),
#   ('already', 'RB'),
#   ('know', 'VBP'),
#   ('the', 'DT'),
#   ('riding', 'VBG'),
#   ('around', 'IN'),
#   ('Cumberland', 'NNP'),
#   ('is', 'VBZ'),
#   ('top', 'JJ'),
#   ('drawer', 'NN'),
#   ('stuff', 'NN'),
#   ('whether', 'IN'),
#   ('you', 'PRP'),
#   ('like', 'IN'),
#   ('XC', 'NNP'),
#   ('DH', 'NNP'),
#   ('or', 'CC'),
#   ('anything', 'NN'),
#   ('in', 'IN'),
#   ('between', 'IN')],
#  [('This', 'DT'),
#   ('is', 'VBZ'),
#   ('a', 'DT'),
#   ('fun', 'JJ'),
#   ('place', 'NN'),
#   ('to', 'TO'),
#   ('stay', 'VB'),
#   ('in', 'IN'),
#   ('a', 'DT'),
#   ('friendly', 'JJ'),
#   ('little', 'JJ'),
#   ('town', 'NN'),
#   ('with', 'IN'),
#   ('lots', 'NNS'),
#   ('going', 'VBG'),
#   ('on', 'IN'),
#   ('if', 'IN'),
#   ('you', 'PRP'),
#   ('enjoy', 'VBP'),
#   ('the', 'DT'),
#   ('great', 'JJ'),
#   ('outdoors', 'NNS'),
#   ('Rooms', 'NNS'),
#   ('are', 'VBP'),
#   ('clean', 'JJ'),
#   ('and', 'CC'),
#   ('comfortable', 'JJ'),
#   ('and', 'CC'),
#   ('the', 'DT'),
#   ('hostel', 'NN'),
#   ('well', 'RB'),
#   ('equipped', 'VBN'),
#   ('and', 'CC'),
#   ('spacious', 'JJ'),
#   ('Large', 'NNP'),
#   ('comfortable', 'JJ'),
#   ('common', 'JJ'),
#   ('room', 'NN'),
#   ('with', 'IN'),
#   ('lots', 'NNS'),
#   ('of', 'IN'),
#   ('space', 'NN'),
#   ('to', 'TO'),
#   ('lounge', 'NN'),
#   ('and', 'CC'),
#   ('eat', 'NN'),
#   ('Kitchen', 'NNP'),
#   ('is', 'VBZ'),
#   ('huge', 'JJ'),
#   ('and', 'CC'),
#   ('very', 'RB'),
#   ('well', 'RB'),
#   ('equipped', 'VBN'),
#   ('with', 'IN'),
#   ('a', 'DT'),
#   ('large', 'JJ'),
#   ('commercial', 'JJ'),
#   ('fridge', 'NN'),
#   ('and', 'CC'),
#   ('bins', 'NNS'),
#   ('for', 'IN'),
#   ('your', 'PRP$'),
#   ('food', 'NN'),
#   ('nThey', 'RB'),
#   ('cater', 'NN'),
#   ('to', 'TO'),
#   ('the', 'DT'),
#   ('bike', 'NN'),
#   ('crowd', 'NN'),
#   ('with', 'IN'),
#   ('bike', 'NN'),
#   ('washing', 'VBG'),
#   ('area', 'NN'),
#   ('and', 'CC'),
#   ('places', 'NNS'),
#   ('to', 'TO'),
#   ('store', 'VB'),
#   ('your', 'PRP$'),
#   ('gear', 'JJ'),
#   ('nTip', 'JJ'),
#   ('ask', 'NN'),
#   ('for', 'IN'),
#   ('a', 'DT'),
#   ('room', 'NN'),
#   ('at', 'IN'),
#   ('the', 'DT'),
#   ('rear', 'JJ'),
#   ('away', 'RB'),
#   ('from', 'IN'),
#   ('common', 'JJ'),
#   ('areas', 'NNS'),
#   ('if', 'IN'),
#   ('you', 'PRP'),
#   ('want', 'VBP'),
#   ('to', 'TO'),
#   ('sleep', 'VB'),
#   ('in', 'IN'),
#   ('On', 'IN'),
#   ('the', 'DT'),
#   ('weekends', 'NNS'),
#   ('there', 'EX'),
#   ('can', 'MD'),
#   ('be', 'VB'),
#   ('a', 'DT'),
#   ('lot', 'NN'),
#   ('of', 'IN'),
#   ('noise', 'NN'),
#   ('fro', 'VBP'),
#   ('the', 'DT'),
#   ('nearby', 'JJ'),
#   ('hotel', 'NN'),
#   ('lounge', 'NN'),
#   ('and', 'CC'),
#   ('yahoos', 'NN'),
#   ('partying', 'NN'),
#   ('after', 'IN'),
#   ('the', 'DT'),
#   ('bars', 'NNS'),
#   ('close', 'RB'),
#   ('nGreat', 'JJ'),
#   ('hospitality', 'NN'),
#   ('and', 'CC'),
#   ('reasonable', 'JJ'),
#   ('base', 'NN'),
#   ('of', 'IN'),
#   ('operation', 'NN')],
#  [('My', 'PRP$'),
#   ('wife', 'NN'),
#   ('and', 'CC'),
#   ('I', 'PRP'),
#   ('stayed', 'VBP'),
#   ('here', 'RB'),
#   ('for', 'IN'),
#   ('4', 'CD'),
#   ('nights', 'NNS'),
#   ('to', 'TO'),
#   ('ride', 'VB'),
#   ('mountain', 'NN'),
#   ('bikes', 'NNS'),
#   ('this', 'DT'),
#   ('place', 'NN'),
#   ('was', 'VBD'),
#   ('amazingly', 'RB'),
#   ('clean', 'JJ'),
#   ('we', 'PRP'),
#   ('had', 'VBD'),
#   ('a', 'DT'),
#   ('private', 'JJ'),
#   ('room', 'NN'),
#   ('that', 'WDT'),
#   ('was', 'VBD'),
#   ('better', 'JJR'),
#   ('than', 'IN'),
#   ('a', 'DT'),
#   ('lot', 'NN'),
#   ('of', 'IN'),
#   ('chain', 'NN'),
#   ('hotels', 'NNS'),
#   ('and', 'CC'),
#   ('the', 'DT'),
#   ('place', 'NN'),
#   ('just', 'RB'),
#   ('had', 'VBD'),
#   ('great', 'JJ'),
#   ('character', 'JJ'),
#   ('Pool', 'NNP'),
#   ('table', 'NN'),
#   ('full', 'JJ'),
#   ('kitchen', 'NN'),
#   ('and', 'CC'),
#   ('located', 'VBN'),
#   ('on', 'IN'),
#   ('the', 'DT'),
#   ('main', 'JJ'),
#   ('street', 'NN'),
#   ('of', 'IN'),
#   ('a', 'DT'),
#   ('sleepy', 'JJ'),
#   ('town', 'NN'),
#   ('with', 'IN'),
#   ('great', 'JJ'),
#   ('outdoor', 'JJ'),
#   ('access', 'NN'),
#   ('Highly', 'NNP'),
#   ('recommened', 'VBD'),
#   ('and', 'CC'),
#   ('bring', 'VB'),
#   ('you', 'PRP'),
#   ('mountain', 'VB'),
#   ('bikes', 'NNS'),
#   ('too', 'RB')],
#  [('When', 'WRB'),
#   ('compared', 'VBN'),
#   ('to', 'TO'),
#   ('other', 'JJ'),
#   ('hostels', 'NNS'),
#   ('on', 'IN'),
#   ('the', 'DT'),
#   ('west', 'NN'),
#   ('coast', 'NN'),
#   ('this', 'DT'),
#   ('hostel', 'NN'),
#   ('ranks', 'VBZ'),
#   ('on', 'IN'),
#   ('the', 'DT'),
#   ('top', 'JJ'),
#   ('5', 'CD'),
#   ('There', 'EX'),
#   ('is', 'VBZ'),
#   ('nothing', 'NN'),
#   ('on', 'IN'),
#   ('which', 'WDT'),
#   ('I', 'PRP'),
#   ('could', 'MD'),
#   ('complain', 'VB'),
#   ('Storage', 'NNP'),
#   ('for', 'IN'),
#   ('skis', 'NN'),
#   ('and', 'CC'),
#   ('mountain', 'NN'),
#   ('bikes', 'NNS'),
#   ('huge', 'JJ'),
#   ('fully', 'RB'),
#   ('equipped', 'VBN'),
#   ('kitchen', 'NN'),
#   ('with', 'IN'),
#   ('bins', 'NNS'),
#   ('for', 'IN'),
#   ('your', 'PRP$'),
#   ('food', 'NN'),
#   ('big', 'JJ'),
#   ('living', 'NN'),
#   ('room', 'NN'),
#   ('area', 'NN'),
#   ('with', 'IN'),
#   ('a', 'DT'),
#   ('lot', 'NN'),
#   ('of', 'IN'),
#   ('things', 'NNS'),
#   ('to', 'TO'),
#   ('do', 'VB'),
#   ('nice', 'JJ'),
#   ('bars', 'NNS'),
#   ('nearby', 'RB'),
#   ('huge', 'JJ'),
#   ('dorms', 'NNS'),
#   ('with', 'IN'),
#   ('comfortable', 'JJ'),
#   ('and', 'CC'),
#   ('stable', 'JJ'),
#   ('beds', 'NNS'),
#   ('Also', 'RB'),
#   ('the', 'DT'),
#   ('people', 'NNS'),
#   ('working', 'VBG'),
#   ('over', 'IN'),
#   ('there', 'EX'),
#   ('are', 'VBP'),
#   ('very', 'RB'),
#   ('friendly', 'JJ'),
#   ('and', 'CC'),
#   ('respectful', 'NN'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('customers', 'NNS'),
#   ('This', 'DT'),
#   ('is', 'VBZ'),
#   ('also', 'RB'),
#   ('the', 'DT'),
#   ('cleanest', 'JJS'),
#   ('hostel', 'NN'),
#   ('I', 'PRP'),
#   ('ve', 'VBP'),
#   ('been', 'VBN'),
#   ('into', 'IN'),
#   ('Happy', 'JJ'),
#   ('10th', 'CD'),
#   ('year', 'NN'),
#   ('anniversary', 'NN')],
#  [('This', 'DT'),
#   ('place', 'NN'),
#   ('is', 'VBZ'),
#   ('amazing', 'VBG'),
#   ('Lovely', 'RB'),
#   ('old', 'JJ'),
#   ('historic', 'JJ'),
#   ('building', 'NN'),
#   ('but', 'CC'),
#   ('beautifully', 'RB'),
#   ('renovated', 'VBD'),
#   ('inside', 'IN'),
#   ('The', 'DT'),
#   ('bathrooms', 'NNS'),
#   ('were', 'VBD'),
#   ('spotless', 'RB'),
#   ('The', 'DT'),
#   ('kitchen', 'NN'),
#   ('was', 'VBD'),
#   ('huge', 'JJ'),
#   ('and', 'CC'),
#   ('incredibly', 'RB'),
#   ('well', 'RB'),
#   ('equipped', 'VBN'),
#   ('e', 'NN'),
#   ('g', 'NN'),
#   ('there', 'EX'),
#   ('were', 'VBD'),
#   ('4', 'CD'),
#   ('ways', 'NNS'),
#   ('to', 'TO'),
#   ('make', 'VB'),
#   ('coffee', 'NN'),
#   ('alone', 'RB'),
#   ('a', 'DT'),
#   ('coffee', 'NN'),
#   ('maker', 'NN'),
#   ('stovetop', 'JJ'),
#   ('espresso', 'NN'),
#   ('makers', 'NNS'),
#   ('french', 'JJ'),
#   ('press', 'NN'),
#   ('and', 'CC'),
#   ('pour', 'NN'),
#   ('over', 'IN'),
#   ('a', 'DT'),
#   ('huge', 'JJ'),
#   ('common', 'JJ'),
#   ('room', 'NN'),
#   ('The', 'DT'),
#   ('staff', 'NN'),
#   ('was', 'VBD'),
#   ('friendly', 'JJ'),
#   ('and', 'CC'),
#   ('helpful', 'JJ'),
#   ('And', 'CC'),
#   ('the', 'DT'),
#   ('people', 'NNS'),
#   ('I', 'PRP'),
#   ('met', 'VBP'),
#   ('there', 'EX'),
#   ('were', 'VBD'),
#   ('super', 'JJR'),
#   ('friendly', 'JJ'),
#   ('and', 'CC'),
#   ('nice', 'JJ'),
#   ('perhaps', 'RB'),
#   ('because', 'IN'),
#   ('it', 'PRP'),
#   ('attracts', 'VBZ'),
#   ('a', 'DT'),
#   ('diverse', 'NN'),
#   ('all', 'DT'),
#   ('ages', 'NNS'),
#   ('crowd', 'VBP'),
#   ('interested', 'JJ'),
#   ('in', 'IN'),
#   ('the', 'DT'),
#   ('outdoors', 'NNS'),
#   ('Stayed', 'NNP'),
#   ('in', 'IN'),
#   ('a', 'DT'),
#   ('private', 'JJ'),
#   ('room', 'NN'),
#   ('which', 'WDT'),
#   ('was', 'VBD'),
#   ('a', 'DT'),
#   ('great', 'JJ'),
#   ('deal', 'NN'),
#   ('small', 'JJ'),
#   ('but', 'CC'),
#   ('very', 'RB'),
#   ('nicely', 'RB'),
#   ('furnished', 'VBN'),
#   ('and', 'CC'),
#   ('comfy', 'JJ'),
#   ('Cumberland', 'NNP'),
#   ('is', 'VBZ'),
#   ('a', 'DT'),
#   ('quiet', 'JJ'),
#   ('little', 'JJ'),
#   ('place', 'NN'),
#   ('but', 'CC'),
#   ('with', 'IN'),
#   ('a', 'DT'),
#   ('few', 'JJ'),
#   ('nice', 'JJ'),
#   ('spots', 'NNS'),
#   ('on', 'IN'),
#   ('the', 'DT'),
#   ('main', 'JJ'),
#   ('street', 'NN'),
#   ('for', 'IN'),
#   ('eating', 'VBG'),
#   ('drinking', 'NN'),
#   ('and', 'CC'),
#   ('shopping', 'NN'),
#   ('It', 'PRP'),
#   ('s', 'VBZ'),
#   ('a', 'DT'),
#   ('little', 'JJ'),
#   ('tough', 'JJ'),
#   ('to', 'TO'),
#   ('get', 'VB'),
#   ('around', 'RB'),
#   ('without', 'IN'),
#   ('a', 'DT'),
#   ('bike', 'NN'),
#   ('or', 'CC'),
#   ('a', 'DT'),
#   ('car', 'NN'),
#   ('though', 'IN')],
#  [('I', 'PRP'),
#   ('loved', 'VBD'),
#   ('my', 'PRP$'),
#   ('time', 'NN'),
#   ('here', 'RB'),
#   ('The', 'DT'),
#   ('hostel', 'NN'),
#   ('has', 'VBZ'),
#   ('a', 'DT'),
#   ('great', 'JJ'),
#   ('atmosphere', 'NN'),
#   ('and', 'CC'),
#   ('a', 'DT'),
#   ('certain', 'JJ'),
#   ('charm', 'NN'),
#   ('nIt', 'NN'),
#   ('is', 'VBZ'),
#   ('a', 'DT'),
#   ('great', 'JJ'),
#   ('place', 'NN'),
#   ('for', 'IN'),
#   ('mountain', 'NN'),
#   ('bikers', 'NNS'),
#   ('nAlthough', 'IN'),
#   ('I', 'PRP'),
#   ('didn', 'VBP'),
#   ('t', 'NNS'),
#   ('have', 'VBP'),
#   ('kids', 'NNS'),
#   ('with', 'IN'),
#   ('my', 'PRP$'),
#   ('I', 'PRP'),
#   ('think', 'VBP'),
#   ('it', 'PRP'),
#   ('would', 'MD'),
#   ('be', 'VB'),
#   ('a', 'DT'),
#   ('fine', 'JJ'),
#   ('environment', 'NN'),
#   ('for', 'IN'),
#   ('families', 'NNS'),
#   ('too', 'RB')]]

# %%
def flatten(npTokenList):
    finalList =[]
    for phrase in npTokenList:
        token = ''
        for word in phrase:
            token += word + ' '
        finalList.append(token.rstrip())
    return finalList

# %%
import itertools

# %%
len(taggedToks)
taggedToks[43:5]
#toks_flat = taggedToks.flat()
merged = list(itertools.chain(*taggedToks))
merged[:4]
# Out:
# [('I', 'PRP'), ('was', 'VBD'), ('looking', 'VBG'), ('for', 'IN')]

# %%
# Defining the chunkstring
grammar = r"""
    NBAR:
        {<NN.*|JJ>*<NN.*>}  # Nouns and Adjectives, terminated with Nouns
        
    NP:
        {<NBAR>}
        {<NBAR><IN><NBAR>}  # Above, connected with in/of/etc...
"""

# %%
# The behaviour of the parser is specified to "grammar" in order to add more structure to the sentence 
# The defined parser uses the POS tagged reviews as input
chunker = nltk.RegexpParser(grammar)
tree= chunker.parse(merged)

# %%
# Noun Phrase Extraction Support Functions
from nltk.corpus import stopwords
stop_words = stopwords.words('english')
# Defining both lemmatizing and stemming - although since lemmatization uses the context to conver the word into the 
# base form - it is predicted to have more value 
lemmatizer = nltk.WordNetLemmatizer()
stemmer = nltk.stem.porter.PorterStemmer()

# generator, generate leaves one by one
def leaves(tree):
    """Finds NP (nounphrase) leaf nodes of a chunk tree."""
    for subtree in tree.subtrees(filter = lambda t: t.label()=='NP' or t.label()=='JJ' or t.label()=='RB'):
        yield subtree.leaves()

# stemming, lematizing, lower case
def normalise(word):
    """Normalises words to lowercase and stems and lemmatizes it."""
    word = word.lower()
    word = stemmer.stem(word)
    word = lemmatizer.lemmatize(word)
    return word

# stop-words and length control
def acceptable_word(word):
    """Checks conditions for acceptable word: length, stopword."""
    accepted = bool(2 <= len(word) <= 400
        and word.lower() not in stop_words)
    return accepted

# generator, create item once a time
def get_terms(tree):
    for leaf in leaves(tree):
        term = [normalise(w) for w,t in leaf if acceptable_word(w) ]
        # Phrase only
        if len(term)>1:
            yield term

# %%
npTokenList = [word for word in get_terms(tree)]
npTokenList[:10]
# Out:
# [['ride', 'fool', 'hostel'],
#  ['cumberland', 'great', 'kitchen'],
#  ['common', 'area', 'comfi', 'bed'],
#  ['nice', 'folk'],
#  ['nearbi', 'mountain', 'bike'],
#  ['big', 'mountain'],
#  ['short', 'distanc'],
#  ['surpris', 'amount'],
#  ['ride', 'fool', 'hostel', 'whilst'],
#  ['mount', 'washington', 'alpin', 'resort']]

# %%
finalList = flatten(npTokenList)

# %%
(finalList[:6])
# Out:
# ['ride fool hostel',
#  'cumberland great kitchen',
#  'common area comfi bed',
#  'nice folk',
#  'nearbi mountain bike',
#  'big mountain']

# %%
# Revise the previous dataframe transform function.
def newDataFrameTransformation(hotelDf, reviewDF, k=50):
    reviews = reviewDF['reviewCol'].values
    
    # Top-k frequent terms
    counter = Counter()
    for review in reviews:
            counter.update(flatten([word
                            for word 
                            in get_terms(chunker.parse(pos_tag(re.findall(r'\w+', review)))) 
                            ]))
    topk = counter.most_common(k)        
    
    #Find out if a particular review has the word from topk list
    freqReview = []
    for i in range(len(reviews)):
        tempCounter = Counter(flatten([word 
                                       for word 
                                       in get_terms(chunker.parse(pos_tag(re.findall(r'\w+',reviews[i]))))]))
        topkinReview = [1 if tempCounter[word] > 0 else 0 for (word,wordCount) in topk]
        freqReview.append(topkinReview)
        
        
    #Prepare freqReviewDf
    freqReviewDf = pd.DataFrame(freqReview)
    dfName = []
    for c in topk:
        dfName.append(c[0])
    freqReviewDf.columns = dfName
    finalreviewDf = reviewDF.join(freqReviewDf)
    #print(topk)
    finaldf = hotelDf[['Hotel_Name','Ratings','Experience']].merge(finalreviewDf)
    
    return topk, finaldf

# %%
reviewNegDF = reviewDF[reviewDF['Experience']=='negative']
#reviewNegDF

# %%
reviewPosDF = reviewDF[reviewDF['Experience']=='positive']
#reviewPosDF

# %%
topk_pos_phrase, finaldf_pos_phrase = newDataFrameTransformation(reviews_df, reviewPosDF)

# %%
topk_neg_phrase, finaldf_neg_phrase = newDataFrameTransformation(reviews_df, reviewNegDF)

# %%
topk_phrase, finaldf_phrase = newDataFrameTransformation(reviews_df, reviewDF)

# %%
for item_a, item_b in zip(topk_pos_phrase, topk_neg_phrase):
    print(item_a,"                   ",item_b)
# Out:
# ('port alberni', 224)                     ('front desk', 88)
# ('hot tub', 153)                     ('port alberni', 36)
# ('great place', 127)                     ('hot tub', 22)
# ('front desk', 116)                     ('credit card', 21)
# ('bedroom suit', 98)                     ('next day', 21)
# ('vancouv island', 94)                     ('park lot', 18)
# ('beach club resort', 86)                     ('next morn', 16)
# ('beach club', 84)                     ('nthe room', 16)
# ('ocean view', 73)                     ('night stay', 16)
# ('friendli staff', 65)                     ('hot water', 16)
# ('full kitchen', 62)                     ('continent breakfast', 15)
# ('front desk staff', 56)                     ('front desk staff', 13)
# ('live room', 52)                     ('coffe maker', 12)
# ('first time', 50)                     ('first time', 12)
# ('comfort bed', 48)                     ('good thing', 11)
# ('great locat', 47)                     ('first room', 11)
# ('great time', 47)                     ('queen bed', 11)
# ('next year', 47)                     ('beach club resort', 11)
# ('short walk', 45)                     ('hotel room', 10)
# ('great view', 45)                     ('first night', 10)
# ('queen bed', 44)                     ('live room', 10)
# ('great stay', 43)                     ('beach club', 10)
# ('hospit inn', 43)                     ('next time', 9)
# ('indoor pool', 40)                     ('doubl bed', 9)
# ('mini golf', 40)                     ('air condition', 9)
# ('good valu', 39)                     ('custom servic', 9)
# ('nthe room', 38)                     ('free wifi', 8)
# ('next time', 36)                     ('good locat', 8)
# ('night stay', 36)                     ('air condit', 8)
# ('nice place', 36)                     ('nice view', 8)
# ('short drive', 35)                     ('ice machin', 8)
# ('beach acr', 35)                     ('room servic', 8)
# ('minut drive', 33)                     ('ground floor', 8)
# ('best western', 33)                     ('main build', 8)
# ('room servic', 33)                     ('best western', 8)
# ('help staff', 32)                     ('poco inn', 8)
# ('easi access', 31)                     ('nthe staff', 7)
# ('rathtrevor beach', 31)                     ('differ room', 7)
# ('hotel staff', 29)                     ('bedroom suit', 7)
# ('oceansid villag resort', 29)                     ('good valu', 7)
# ('great experi', 28)                     ('clean staff', 7)
# ('next morn', 28)                     ('main road', 7)
# ('eagl nook', 28)                     ('vancouv island', 7)
# ('good food', 27)                     ('hospit inn', 7)
# ('wonder stay', 27)                     ('nice place', 7)
# ('coffe maker', 27)                     ('hair dryer', 7)
# ('hotel room', 27)                     ('hotel restaur', 6)
# ('perfect place', 26)                     ('friendli staff', 6)
# ('second floor', 25)                     ('long time', 6)
# ('first night', 25)                     ('whole place', 6)

# %% [markdown]
# #### Repeating this analysis for the top-50 noun phrases and summarization of findings:
# The positive reviews contained more objectively positive phrases that were used such as "great time", "great view", infact even though the word "great" appeared in the top negative reviews, the phrases only appears in the positive context. The phrases in the negative list are sometimes positive phrases (like, "good thing", "good location", "best western", "clean staff")- this goes to show that people generally tend to say positive things about a hotel while saying negative things about it. The phrases made it easier to figure out the specific aspects of the hotel industries that people mostly talk about/interact with, like the "front desk" and they often talk about how their stay affects the "next time".

# %% [markdown]
# ###  Mutual Information:
# #### (a) Use mutual information (MI) with ground truth sentiment to rank the top-50 most sentiment- bearing non-stopwords in the review collection.

# %%
def dataFrameTransformation(hotelDf, reviewDF, k=50):
    reviews = reviewDF['reviewCol'].values
    
    stop = set(stopwords.words('english'))
    
    # Top-k frequent terms
    counter = Counter()
    for review in reviews:
            counter.update([word.lower() 
                            for word 
                            in re.findall(r'\w+', review) 
                            if word.lower() not in stop and len(word) > 2])
    topk = counter.most_common(k)        
    
    #Find out if a particular review has the word from topk list
    freqReview = []
    for i in range(len(reviews)):
        tempCounter = Counter([word.lower() for word in re.findall(r'\w+',reviews[i])])
        topkinReview = [1 if tempCounter[word] > 0 else 0 for (word,wordCount) in topk]
        freqReview.append(topkinReview)
    
    #Prepare freqReviewDf
    freqReviewDf = pd.DataFrame(freqReview)
    dfName = []
    for c in topk:
        dfName.append(c[0])
    freqReviewDf.columns = dfName
    finalreviewDf = reviewDF.join(freqReviewDf)
    finaldf = hotelDf[['Hotel_Name','Ratings','Experience']].merge(finalreviewDf)
    return topk, finaldf

# %%
topk, finaldf = dataFrameTransformation(reviews_df, reviewDF, k=50)

# %%
topk[:10]
# Out:
# [('room', 3445),
#  ('stay', 2198),
#  ('great', 2144),
#  ('hotel', 2143),
#  ('clean', 1874),
#  ('staff', 1788),
#  ('would', 1540),
#  ('good', 1440),
#  ('beach', 1407),
#  ('stayed', 1398)]

# %%
tempDF_pos = reviews_df[reviews_df['Experience']=='positive']
temp_topk, temp_finaldf = dataFrameTransformation(tempDF_pos, reviewDF, k=50)

# %%
def getMI(topk, df, label_column='Experience'):
    miScore = []
    for word in topk:
        miScore.append([word[0]]+[metrics.mutual_info_score(df[label_column], df[word[0]])])
    miScoredf = pd.DataFrame(miScore).sort_values(1,ascending=0)
    miScoredf.columns = ['Word','MI Score']
    return miScoredf

# %%
#MI_neg = getMI(result_neg, finaldf)
#MI_pos = getMI(result_pos, finaldf)
MI_topk = getMI(topk,finaldf)

# %%
MI_topk.head()
# Out:
#      Word  MI Score
# 2   great  0.004182
# 8   beach  0.003794
# 0    room  0.002913
# 3   hotel  0.002242
# 19  night  0.002160

# %%
#temp_topk, temp_finaldf
MI_topk = getMI(temp_topk, temp_finaldf)

# %%
MI_topk.head()
# Out:
#            Word      MI Score
# 43    recommend  1.804112e-15
# 25      service  1.776357e-15
# 16  comfortable  1.776357e-15
# 34          two  1.776357e-15
# 32          get  1.776357e-15

# %% [markdown]
# <b> Interesting and/or locale-specific aspects of these top-ranked words </b><br>
# The scores for mutual information are low which goes to say that there is small dependency between the word and the ground truth of the review. Another aspect of the list is that it was taken from the entire collection of reviews without filtering the positive and negative reviews. This is especially problematic because some of the words (like great) appear in both positive and negative reviews a number of times, hence confusing the model. <br> It should also be noted that the topk words retrieved from the previous function is repeated here and this is due the fact that the MI takes into consideration the number of times a word appreas in the given collection. Therefore, the more frequent a word appears, the more information it would seem to have.

# %% [markdown]
# #### (b) Repeating this analysis for the top-50 noun phrases

# %%
MI_phrases = getMI(topk_phrase, finaldf_phrase)

# %%
MI_phrases.head()
# Out:
#             Word  MI Score
# 1     front desk  0.001611
# 4   bedroom suit  0.001110
# 3    great place  0.000901
# 11  full kitchen  0.000692
# 8     ocean view  0.000662

# %% [markdown]
# The Mutual information scores are significantly smaller than MI scores of induvidual words. This goes to say that the phrases present here are indpendent of the information (positive or negative) they are trying to convey. Furthermore, the number of times the phrases occur in the collection is significantly smaller than the induvidual words occuring. This also affects the MI score. The phrases picked out, like "mini golf" or "indoor pool" are relevant to only a few hotels and its reviews, and therefore cannot be an indicator of how positive or negative the entire hotel staying experience would be.

# %% [markdown]
# ### Pointwise Mutual Information
# #### PMI for the top-50 words with positive and negative reviews.

# %%
def pmiCal(df, x):
    pmilist=[]
    for i in (['positive','negative']):
        for j in [0,1]:
            px = sum(df['Experience']==i)/len(df)
            py = sum(df[x]==j)/len(df)
            pxy = len(df[(df['Experience']==i) & (df[x]==j)])/len(df)
            if pxy==0:#Log 0 cannot happen
                pmi = math.log((pxy+0.0001)/(px*py))
            else:
                pmi = math.log(pxy/(px*py))
            pmilist.append([i]+[j]+[px]+[py]+[pxy]+[pmi])
    pmidf = pd.DataFrame(pmilist)
    pmidf.columns = ['x','y','px','py','pxy','pmi']
    return pmidf

# %%
pmiCal(finaldf,'hotel')
# Out:
#           x  y        px        py       pxy       pmi
# 0  positive  0  0.969886  0.664623  0.650177  0.008601
# 1  positive  1  0.969886  0.335377  0.319709 -0.017267
# 2  negative  0  0.030114  0.664623  0.014446 -0.326035
# 3  negative  1  0.030114  0.335377  0.015668  0.439129

# %%
def pmiIndivCal(df,x,gt, label_column='Experience'):
    px = sum(df[label_column]==gt)/len(df)
    py = sum(df[x]==1)/len(df)
    pxy = len(df[(df[label_column]==gt) & (df[x]==1)])/len(df)
    if pxy==0:#Log 0 cannot happen
        pmi = math.log((pxy+0.0001)/(px*py))
    else:
        pmi = math.log(pxy/(px*py))
    return pmi

# %%
pmiIndivCal(finaldf,'hotel','positive')
# Out:
# -0.017267140740509255

# %%
def pmiForAllCal(df, label_column='Experience', topk=topk):
    #Try calculate all the pmi for top k and store them into one pmidf dataframe
    pmilist = []
    pmiposlist = []
    pmineglist = []
    for word in topk:
        pmilist.append([word[0]]+[pmiCal(df,word[0])])
        pmiposlist.append([word[0]]+[pmiIndivCal(df,word[0],'positive',label_column)])
        pmineglist.append([word[0]]+[pmiIndivCal(df,word[0],'negative',label_column)])
    pmidf = pd.DataFrame(pmilist)
    pmiposlist = pd.DataFrame(pmiposlist)
    pmineglist = pd.DataFrame(pmineglist)
    pmiposlist.columns = ['word','pmi']
    pmineglist.columns = ['word','pmi']
    pmidf.columns = ['word','pmi']
    return pmiposlist, pmineglist, pmidf

# %%
pmiposlist, pmineglist, pmidf = pmiForAllCal(finaldf)

# %%
#Sorted top pmi words for positive reviews
pmiposlist.sort_values('pmi',ascending=0).head()
# Out:
#            word       pmi
# 48    beautiful  0.020880
# 31      helpful  0.020150
# 8         beach  0.017515
# 2         great  0.017327
# 16  comfortable  0.015198

# %%
#Sorted top pmi words for positive reviews
pmineglist.sort_values('pmi',ascending=0).head()
# Out:
#          word       pmi
# 29       quot  0.869468
# 19      night  0.666707
# 32        get  0.626517
# 17  breakfast  0.583484
# 39      could  0.517864

# %% [markdown]
# #### PMI concluding remarks:
# The PMI scores are higher than just the mutual information scores, this is because mutual information scores are an average of all the senarios in which the term and the emotion are present and as previously established, there is considerable over lap of words being present in both the lists. PMI however involves itself for the word in the positive or negative context only, the ambiguity is removed. Therefore, the number of words present from a postive or negative review is already classified and word is then better associated with that classification.

# %%
pmiposlist_phrase, pmineglist_phrase, pmidf_phrase = pmiForAllCal(finaldf_phrase,topk = topk_phrase)

# %%
pmiposlist_phrase.sort_values('pmi',ascending=0).head()
# Out:
#                 word       pmi
# 47       easi access  0.030577
# 11      full kitchen  0.028695
# 3        great place  0.028677
# 44        help staff  0.027929
# 45  rathtrevor beach  0.026653

# %%
pmineglist_phrase.sort_values('pmi',ascending=0).head()
# Out:
#                    word       pmi
# 40  continent breakfast  1.762871
# 27            next morn  1.290543
# 32             next day  1.270637
# 30             park lot  1.175454
# 1            front desk  1.041710

# %% [markdown]
# #### PMI for top-50 noun phrases concluding notes:
# The same phrases were repeated for the phrases for the positive and negative reviews, with opposite signs. This is because the top K phrases are gotten from the same dataframe, and are mapped to opposite classes (positive and negative), The topk words remain constant as they are from the same dataframe, but the context they are applied to are different (positive/negative) - hence the opposite signs for the different lists.<br>
# The values are different because of the number of times a certain phrase is repeated in the positive context is different then the number of times it is repeated in the negative context. <br> Over all the values for the PMI was larger than that for just MI because mututal information was an average of all the occurrence of the terms and a lot of the times, the terms exisited in both the positive and the negative context, hence the words were not able to learn if its occurrence was to do with positive or the negative class. For PMI, we are splitting it into the negative and positive lists, therefore if a phrase exists in a negative tweet, it has more information to give with regards to the negative tweet.

# %% [markdown]
# #### Analysis repeated for the single top and single bottom hotel (according to the ground truth rating).

# %%
# Single top hotel: Stansbury&#39;s Guest House
# Single bottom hotel: Howard Johnson Hotel Port Alberni

# %%
best_hotel_df = reviews_df[reviews_df['Hotel_Name']=='Stansbury&#39;s Guest House']
worst_hotel_df = reviews_df[reviews_df['Hotel_Name']=='Howard Johnson Hotel Port Alberni']
best_hotel_df.head()
# Out:
#                                       Link                   Hotel_Name  \
# 28  data/ca/1015432/3589554/163624982.html  Stansbury&#39;s Guest House
# 29  data/ca/1015432/3589554/165371253.html  Stansbury&#39;s Guest House
# 30  data/ca/1015432/3589554/169057536.html  Stansbury&#39;s Guest House
# 31  data/ca/1015432/3589554/210674359.html  Stansbury&#39;s Guest House
# 32  data/ca/1015432/3589554/215774198.html  Stansbury&#39;s Guest House
#
#                                           Review text  Ratings Experience
# 28  "Stayed for a week in the Stansbury\\'s guest ...        5   positive
# 29  "A group of 6 of us stayed here for a weekend ...        5   positive
# 30  "Visiting from New Zealand,we were fortunate t...        5   positive
# 31  "Gwen and Scott have a beautiful Guest House a...        5   positive
# 32  "A beautifully finished apartment with every c...        5   positive

# %%
BestWorst_DF = best_hotel_df.append(worst_hotel_df)
BestWorst_DF
BestWorst_DF.rename(columns={'Review text':'reviewCol'},inplace=True)
BestWorst_DF.head()
# Out:
#                                       Link                   Hotel_Name  \
# 28  data/ca/1015432/3589554/163624982.html  Stansbury&#39;s Guest House
# 29  data/ca/1015432/3589554/165371253.html  Stansbury&#39;s Guest House
# 30  data/ca/1015432/3589554/169057536.html  Stansbury&#39;s Guest House
# 31  data/ca/1015432/3589554/210674359.html  Stansbury&#39;s Guest House
# 32  data/ca/1015432/3589554/215774198.html  Stansbury&#39;s Guest House
#
#                                             reviewCol  Ratings Experience
# 28  "Stayed for a week in the Stansbury\\'s guest ...        5   positive
# 29  "A group of 6 of us stayed here for a weekend ...        5   positive
# 30  "Visiting from New Zealand,we were fortunate t...        5   positive
# 31  "Gwen and Scott have a beautiful Guest House a...        5   positive
# 32  "A beautifully finished apartment with every c...        5   positive

# %%
Ratings = BestWorst_DF['Ratings']
reviewDF = pd.concat([reviewDF, Ratings],axis =1 )
#reviewDF.rename(columns={'exp_index':'Ratings'},inplace=True)

# %%
topk_bestworst, final_bestworstDF = dataFrameTransformation(reviewDF,BestWorst_DF, k=50)
topk_bestworst[:10]
# Out:
# [('room', 110),
#  ('stay', 80),
#  ('hotel', 64),
#  ('clean', 61),
#  ('gwen', 60),
#  ('great', 59),
#  ('place', 55),
#  ('scott', 46),
#  ('stayed', 45),
#  ('cumberland', 43)]

# %%
def pmiCal1(df, x):
    pmilist=[]
    for i in ['positive','negative']:
        for j in [0,1]:
            px = sum(df['Experience']==i)/len(df)
            py = sum(df[x]==j)/len(df)
            pxy = len(df[(df['Experience']==i) & (df[x]==j)])/len(df)
            if pxy==0:#Log 0 cannot happen
                if (px == 0 or py == 0):
                    pmi = math.log((pxy+0.0001)/(px*py+0.0001))
                else:
                    pmi = math.log((pxy+0.0001)/(px*py))
            else:
                pmi = math.log(pxy/(px*py))
            pmilist.append([i]+[j]+[px]+[py]+[pxy]+[pmi])
    pmidf = pd.DataFrame(pmilist)
    pmidf.columns = ['x','y','px','py','pxy','pmi']
    return pmidf

# %%
def pmiIndivCal1(df,x,gt, label_column='Experience'):
    pmi = 0
    px = sum(df[label_column]==gt)/len(df)
    py = sum(df[x]==1)/len(df)
    pxy = len(df[(df[label_column]==gt) & (df[x]==1)])/len(df)
    if pxy==0:#Log 0 cannot happen
        if (px ==0 or py == 0):
            pmi = math.log((pxy+0.0001)/(px*py+0.0001))
        else: 
            pmi = math.log((pxy+0.0001)/(px*py))
    else:
        pmi = math.log(pxy/(px*py))
    return pmi

# %%
def pmiForAllCal1(df, label_column='Experience', topk=topk):
    #Try calculate all the pmi for top k and store them into one pmidf dataframe
    pmilist = []
    pmiposlist = []
    pmineglist = []
    for word in topk:
        pmilist.append([word[0]]+[pmiCal1(df,word[0])])
        pmiposlist.append([word[0]]+[pmiIndivCal1(df,word[0],'positive',label_column)])
        pmineglist.append([word[0]]+[pmiIndivCal1(df,word[0],'negative',label_column)])
    pmidf = pd.DataFrame(pmilist)
    pmiposlist = pd.DataFrame(pmiposlist)
    pmineglist = pd.DataFrame(pmineglist)
    pmiposlist.columns = ['word','pmi']
    pmineglist.columns = ['word','pmi']
    pmidf.columns = ['word','pmi']
    return pmiposlist, pmineglist, pmidf

# %%
pmiposlist_bestHotel, pmineglist_bestHotel, pmidf_bestHotel = pmiForAllCal(final_bestworstDF, topk = topk_bestworst)

# %%
#Sorted top pmi words for positive reviews
y = pmiposlist_bestHotel.sort_values('pmi',ascending=0)
y
# Out:
#            word       pmi
# 0          room  0.351376
# 37         nice  0.351376
# 27         back  0.351376
# 28        hosts  0.351376
# 29     location  0.351376
# 30        could  0.351376
# 31         well  0.351376
# 32     bathroom  0.351376
# 33         home  0.351376
# 34         town  0.351376
# 35         much  0.351376
# 36          old  0.351376
# 38   everything  0.351376
# 1          stay  0.351376
# 39         also  0.351376
# 40         even  0.351376
# 41      perfect  0.351376
# 42         like  0.351376
# 43         nthe  0.351376
# 44          amp  0.351376
# 45        suite  0.351376
# 46        night  0.351376
# 47          get  0.351376
# 48       trails  0.351376
# 26          two  0.351376
# 25  comfortable  0.351376
# 24         quot  0.351376
# 13        would  0.351376
# 2         hotel  0.351376
# 3         clean  0.351376
# 4          gwen  0.351376
# 7         scott  0.351376
# 8        stayed  0.351376
# 9    cumberland  0.351376
# 10        staff  0.351376
# 11        rooms  0.351376
# 23     mountain  0.351376
# 12        house  0.351376
# 15        guest  0.351376
# 16    stansbury  0.351376
# 17         good  0.351376
# 18     friendly  0.351376
# 19         bike  0.351376
# 20         time  0.351376
# 22      helpful  0.351376
# 49         area  0.351376
# 14    breakfast  0.351376
# 6         place  0.351376
# 5         great  0.351376
# 21          one  0.351376

# %%
#Sorted top pmi words for positive reviews
x = pmineglist_bestHotel.sort_values('pmi',ascending=0)
x.head()
# Out:
#         word       pmi
# 24      quot -3.544844
# 44       amp -4.679174
# 43      nthe -4.713661
# 32  bathroom -4.931138
# 46     night -4.931138

# %%
topk_best1, final_bestDF1 = dataFrameTransformation(best_hotel_df,reviewDF, k=50)
#topk_best1

# %%
pmiposlist_bestHotel, pmineglist_bestHotel, pmidf_bestHotel = pmiForAllCal1(final_bestDF1, topk = topk_best1)

# %% [markdown]
# #### Hotel-specic insights about what is good and bad about these two hotels:
# The positive list did contain valuable information such that the guests particularly like their stay depending on their "breakfast" or the "place", or the "location. The positive PMI value indicates that there was a strong correlation between the words and ratings they got. The negative list however, proved to be less informative as all the values were negative, which indicates that the terms cooccured less frequently with the negative class. This could be due to the fact that there were perhaps not many entries in the database to derive enough assupmtions.

# %% [markdown]
# ### Q5. General Plots
# #### (a) Histogram of ground truth and vader sentiments scores:

# %%
x = reviews_df['Ratings']
x_df = pd.DataFrame(x)
review_temp_df = reviewDF.copy()
reviewDF_graphs = pd.concat([review_temp_df, x_df], axis = 1)
reviewDF_graphs.head()
cols = []
count = 1
for column in reviewDF_graphs.columns:
    if column == 'Ratings':
        cols.append('Ratings_'+str(count))
        count+=1
        continue
    cols.append(column)
reviewDF_graphs.columns = cols
reviewDF_graphs.head()
# Out:
#                                            reviewCol   vader Experience  \
# 0  "I was looking for a place to sit and chill fo...  0.8442   positive
# 1  "I stayed at the Riding Fool Hostel whilst I w...  0.9965   positive
# 2  "My husband and I (both in our 50\\'s) stayed ...  0.9757   positive
# 3  "We were warmly  welcomed by Caitlin, the new ...  0.9766   positive
# 4  "Comfortable, cheap, and cosy accommodation wi...  0.4939   positive
#
#                Hotel_Name  exp_index  Ratings_1  Ratings_2
# 0  The Riding Fool Hostel          1        NaN          5
# 1  The Riding Fool Hostel          1        NaN          5
# 2  The Riding Fool Hostel          1        NaN          5
# 3  The Riding Fool Hostel          1        NaN          5
# 4  The Riding Fool Hostel          1        NaN          5

# %%
def getHistogram(measure, title):
    if measure=='both':
        x = [finaldf['Ratings'].values/5]
        y = [finaldf['vader'].values]
        bins = np.linspace(-1, 1, 100)
        plt.title(title)
        plt.hist(x, bins, label='Ratings')
        plt.hist(y, bins, label='Vader Score')
        plt.legend(loc='upper right')
        plt.show()
    
    else:
        plt.hist(finaldf[measure].values)
        plt.title(title)
        plt.xlabel("Value")
        plt.ylabel("Frequency")
        fig = plt.gcf()

# %%
getHistogram('vader', 'Vadar Sentiment Analysis')

# %%
x = finaldf['Ratings'].values
x = finaldf['Hotel_Name'].values
type(x[5])
# Out:
# str

# %%
getHistogram('Ratings', 'Experience')

# %% [markdown]
# #### Differences
# While people experience (1-5 ratings) was quantified, the actual remarks given by the people paint a different story. This is in line with a previous observation, that even when giving a hotel a negative remark, there is some aspect of the review which is a positive remark followed by a "but". Therefore, it is fathomable that hotels with lower ratings would also be given a higher vader score, if their review had some positive comment in it.

# %%
getHistogram('both', 'Experience vs vader')

# %%
# !pip install plotly
# Out:
# Requirement already satisfied: plotly in /Users/krutheekarajkumar/anaconda3/lib/python3.7/site-packages (4.1.1)
# Requirement already satisfied: retrying>=1.3.3 in /Users/krutheekarajkumar/anaconda3/lib/python3.7/site-packages (from plotly) (1.3.3)
# Requirement already satisfied: six in /Users/krutheekarajkumar/anaconda3/lib/python3.7/site-packages (from plotly) (1.12.0)

# %%
import plotly.graph_objs as go

# %%
a = finaldf['Hotel_Name']

#df.sort_values(by='val', ascending=False)

def count_elements(seq) -> dict:
    """Tally elements from `seq`."""
    hist = {}
    for i in seq:
        hist[i] = hist.get(i, 0) + 1
    return hist

count = count_elements(a)
keys = list(count.keys())
vals = list(count.values())
#count_sorted = sorted(count.values())
type(keys)
data_tuples = list(zip(keys,vals))
count = pd.DataFrame(data_tuples, columns=['Hotel','count'])
count_sorted = count.sort_values(by = ['count'])

# %%
fig, ax = plt.subplots(figsize=(17,5))
plt.setp(plt.xticks()[1], rotation=90)
sns.catplot(x='Hotel', y ='count', palette="ch:.25", kind= 'bar', data=count_sorted, ax = ax);
plt.close(2)
plt.title('Hotel reviews count')
ax.set(xlabel='Hotel names', ylabel='Count')
plt.show()

# %% [markdown]
# #### (b) Boxplots for ground truth and vader sentiment:

# %%
sns.catplot(x="Experience", y="Ratings_2", kind="box", data=reviewDF_graphs);

# %%
reviewDF_graphs
# Out:
#                                               reviewCol   vader Experience  \
# 0     "I was looking for a place to sit and chill fo...  0.8442   positive
# 1     "I stayed at the Riding Fool Hostel whilst I w...  0.9965   positive
# 2     "My husband and I (both in our 50\\'s) stayed ...  0.9757   positive
# 3     "We were warmly  welcomed by Caitlin, the new ...  0.9766   positive
# 4     "Comfortable, cheap, and cosy accommodation wi...  0.4939   positive
# 5     "This is a fun place to stay in a friendly lit...  0.9842   positive
# 6     "My wife and I stayed here for 4 nights to rid...  0.9370   positive
# 7     "When compared to other hostels on the west co...  0.9692   positive
# 8     "This place is amazing. Lovely old historic bu...  0.9960   positive
# 9     "I loved my time here. The hostel has a great ...  0.9565   positive
# 10    "Considering this place has a star from the 20...  0.1021   negative
# 11    "Had a great experience at this hostel! The st...  0.9170   positive
# 12    "The common area is awesome. Had a great few d...  0.9392   positive
# 13    "I couldn\\'t agree more with the other positi...  0.9885   positive
# 14    "The hostel itself is good and clean with a hu...  0.3612   negative
# 15    "I should have brought my mountain bike on thi...  0.9694   positive
# 16    "Arrived August 6th 2016 and the first thing I...  0.9891   positive
# 17    "Our two night stay alone in a three bed room ...  0.9787   positive
# 18    "Second time my boyfriend and i stayed here an...  0.9432   positive
# 19    "Super friendly staff. Really clean and an awe... -0.7205   positive
# 20    "My biggest complaint with the Riding Fool is ...  0.8000   negative
# 21    "We have stayed at Riding Fool twice now.  Bot...  0.6028   positive
# 22    "I had my first hosteling experience at the Ri...  0.4915   positive
# 23    "Stayed in Room 7 recently. Noise from the sta...  0.7506   negative
# 24    "Great hostel, very clean, well run, good faci...  0.9704   positive
# 25    "This hostel occupies the first floor (upstair...  0.9942   positive
# 26    "We stayed here as a stop off on our way to No...  0.9022   positive
# 27    "We stayed for one night here as a stop off be...  0.9825   positive
# 28    "Stayed for a week in the Stansbury\\'s guest ...  0.8682   positive
# 29    "A group of 6 of us stayed here for a weekend ...  0.9367   positive
# ...                                                 ...     ...        ...
# 4029  "My family had a very comfortable stay here. O...  0.9843   positive
# 4030  "I haven\\'t been to this motel but I can cert... -0.9493   negative
# 4031  "Hotel was pretty basic but the rates were ver...  0.9793   positive
# 4032  "We stay in one bed room it is cheap but reall...  0.1154   negative
# 4033  "Motels have always been something that concer...  0.9780   positive
# 4034  "Paradise Seashell Motel is in an excellent lo...  0.9958   negative
# 4035  "We stayed at this busy place on our way to To...  0.9638   positive
# 4036  "We stayed September long before school starte...  0.9686   positive
# 4037  "My 11 year old son &amp; I took a trip to Par...  0.9963   positive
# 4038  "We stayed here a couple of weeks ago for two ...  0.9466   positive
# 4039  "The only reason I rated this a 3 was that it ...  0.8834   negative
# 4040  "This simple roadside motel puts the bar very ...  0.9578   positive
# 4041  "We come to Parksville every summer and stay f...  0.9541   positive
# 4042  "My teenagers and I spent a night here on our ...  0.5346   positive
# 4043  "Clean rooms, close to the beach and free mini...  0.8402   negative
# 4044  "This hotel is small but clean enough. In the ... -0.5712   negative
# 4045  "We stayed one night on our way to Tofino and ...  0.9092   positive
# 4046  "Stayed at this location for 3 nights.  The un...  0.9423   positive
# 4047  "We stayed a couple nights just before New Yea...  0.8977   negative
# 4048  "We required an overnight on Christmas Day to ...  0.8680   positive
# 4049  "We have stayed there twice now; both times fo...  0.9161   positive
# 4050  "First, this photo is a misrepresentation. Thi...  0.9279   positive
# 4051  "I really like this little place but they have...  0.4471   positive
# 4052  "Had to spend the night unexpectedly in Parksv...  0.8621   positive
# 4053  "While I did not need a full fledged motel roo...  0.2396   positive
# 4054  "Stayed here this year with Grandma and the li...  0.9771   negative
# 4055  "I reserved a room at this hotel. They called ... -0.9817   negative
# 4056  "Good location and good value for the price.  ...  0.9524   positive
# 4057  "The reception staff were friendly and helpful...  0.1655   negative
# 4058  "We stayed here for one night on a week long t...  0.9363   positive
#
#                        Hotel_Name  exp_index  Ratings_1  Ratings_2
# 0          The Riding Fool Hostel          1        NaN          5
# 1          The Riding Fool Hostel          1        NaN          5
# 2          The Riding Fool Hostel          1        NaN          5
# 3          The Riding Fool Hostel          1        NaN          5
# 4          The Riding Fool Hostel          1        NaN          5
# 5          The Riding Fool Hostel          1        NaN          5
# 6          The Riding Fool Hostel          1        NaN          5
# 7          The Riding Fool Hostel          1        NaN          5
# 8          The Riding Fool Hostel          1        NaN          5
# 9          The Riding Fool Hostel          1        NaN          5
# 10         The Riding Fool Hostel          0        NaN          2
# 11         The Riding Fool Hostel          1        NaN          5
# 12         The Riding Fool Hostel          1        NaN          5
# 13         The Riding Fool Hostel          1        NaN          5
# 14         The Riding Fool Hostel          0        NaN          3
# 15         The Riding Fool Hostel          1        NaN          5
# 16         The Riding Fool Hostel          1        NaN          4
# 17         The Riding Fool Hostel          1        NaN          5
# 18         The Riding Fool Hostel          1        NaN          5
# 19         The Riding Fool Hostel          1        NaN          4
# 20         The Riding Fool Hostel          0        NaN          3
# 21         The Riding Fool Hostel          1        NaN          5
# 22         The Riding Fool Hostel          1        NaN          5
# 23         The Riding Fool Hostel          0        NaN          3
# 24         The Riding Fool Hostel          1        NaN          5
# 25         The Riding Fool Hostel          1        NaN          5
# 26         The Riding Fool Hostel          1        NaN          5
# 27         The Riding Fool Hostel          1        NaN          4
# 28    Stansbury&#39;s Guest House          1        5.0          5
# 29    Stansbury&#39;s Guest House          1        5.0          5
# ...                           ...        ...        ...        ...
# 4029      Paradise Seashell Motel          1        NaN          5
# 4030      Paradise Seashell Motel          0        NaN          1
# 4031      Paradise Seashell Motel          1        NaN          4
# 4032      Paradise Seashell Motel          0        NaN          1
# 4033      Paradise Seashell Motel          1        NaN          5
# 4034      Paradise Seashell Motel          0        NaN          3
# 4035      Paradise Seashell Motel          1        NaN          4
# 4036      Paradise Seashell Motel          1        NaN          4
# 4037      Paradise Seashell Motel          1        NaN          5
# 4038      Paradise Seashell Motel          1        NaN          5
# 4039      Paradise Seashell Motel          0        NaN          3
# 4040      Paradise Seashell Motel          1        NaN          5
# 4041      Paradise Seashell Motel          1        NaN          4
# 4042      Paradise Seashell Motel          1        NaN          4
# 4043      Paradise Seashell Motel          0        NaN          3
# 4044      Paradise Seashell Motel          0        NaN          3
# 4045      Paradise Seashell Motel          1        NaN          5
# 4046      Paradise Seashell Motel          1        NaN          4
# 4047      Paradise Seashell Motel          0        NaN          3
# 4048      Paradise Seashell Motel          1        NaN          4
# 4049      Paradise Seashell Motel          1        NaN          4
# 4050      Paradise Seashell Motel          1        NaN          4
# 4051      Paradise Seashell Motel          1        NaN          4
# 4052      Paradise Seashell Motel          1        NaN          5
# 4053      Paradise Seashell Motel          1        NaN          4
# 4054      Paradise Seashell Motel          0        NaN          3
# 4055      Paradise Seashell Motel          0        NaN          1
# 4056      Paradise Seashell Motel          1        NaN          4
# 4057      Paradise Seashell Motel          0        NaN          3
# 4058      Paradise Seashell Motel          1        NaN          5
#
# [4059 rows x 7 columns]

# %%
top_5_GT
stansbury_GT = reviewDF[reviewDF.Hotel_Name == 'Stansbury&#39;s Guest House']
Cedar_Song_GT = reviewDF[reviewDF.Hotel_Name == 'Cedar Song B&amp;B and Cottage']
Stamp_Falls_GT = reviewDF[reviewDF.Hotel_Name == 'Stamp Falls B &amp; B']
Mozey_On_Inn_GT = reviewDF[reviewDF.Hotel_Name == 'Mozey-On-Inn']
Nimpo_Lake_GT = reviewDF[reviewDF.Hotel_Name == 'Nimpo Lake Resort']

gt_df1 = pd.concat([stansbury_GT,Cedar_Song_GT],axis = 0)
gt_df2 = pd.concat([gt_df1,Stamp_Falls_GT],axis = 0)
gt_df3 = pd.concat([gt_df2,Mozey_On_Inn_GT],axis = 0)
gt_df4 = pd.concat([gt_df3,Nimpo_Lake_GT],axis = 0)

# %%
gt_df4
# Out:
#                                              reviewCol   vader Experience  \
# 28   "Stayed for a week in the Stansbury\\'s guest ...  0.8682   positive
# 29   "A group of 6 of us stayed here for a weekend ...  0.9367   positive
# 30   "Visiting from New Zealand,we were fortunate t...  0.9652   positive
# 31   "Gwen and Scott have a beautiful Guest House a...  0.9803   positive
# 32   "A beautifully finished apartment with every c...  0.9807   positive
# 33   "We happended upon Stansbury\\'s last year jus...  0.9860   positive
# 34   "We stayed at Stansbury`s Guest House for 8 da...  0.9940   positive
# 35   "We had an amazing stay at the Stansbury\\'s G...  0.9665   positive
# 36   "Nine of us spent the weekend at the Stansbury...  0.9443   positive
# 37   "This place has: very friendly hosts, is super...  0.9588   positive
# 38   "Cumberland is cute little village in the Como...  0.9638   positive
# 39   "My wife and I stayed at Stansbury\\'s Guest H...  0.8962   positive
# 40   "You will not be disappointed!  The rooms and ...  0.8551   positive
# 41   "What a wonderful Guest House to call home for...  0.9273   positive
# 42   "This house was clean and had a beautiful sunn...  0.9716   positive
# 43   "My sister and I just spent 10 days at the Gue...  0.8937   positive
# 44   "I hardly want to share this gem so that Gwen\...  0.9757   positive
# 45   "What a great place!  1, 2, or 3 bedrooms.  Bi...  0.9864   positive
# 46   "Right from the beginning Stansbury\\'s Guest ...  0.9532   positive
# 47   "Gwen and Scott.\\n\\nOur stay was Fantastic!!...  0.9576   positive
# 48   "My husband and I stayed at Stansbury\\'s with...  0.9466   positive
# 49   "We have stayed at Stansbury\\'s Guest House a...  0.9744   positive
# 50   "I finally made my way to Cumberland and at th...  0.9836   positive
# 51   "Great location! Close to trails, pubs, food a...  0.9718   positive
# 52   "My Husband and I came for a mountain bike vac...  0.9895   positive
# 53   "Gwen &amp; Scott have created a wonderful san...  0.9897   positive
# 54   "Scott and Gwen made us very welcome. I rode w...  0.8761   positive
# 55   "The hosts are warm and inviting and the 3 bed...  0.9545   positive
# 56   "A perfect place to stay if you want a peacefu...  0.9700   positive
# 57   "Always on the lookout for interesting places ...  0.9881   positive
# ..                                                 ...     ...        ...
# 731  "Our group was attending a wedding in Granite ...  0.9876   positive
# 732  "A fabulous little gem, the owners passion for...  0.9260   positive
# 733  "What a wonderful, comfortable, and pleasant f...  0.9810   positive
# 734  "Absolute gem of a place. Cleanest room you wi...  0.6808   positive
# 735  "Very charming little gem in Coalmont. We stay...  0.9757   positive
# 736  "We had a great stay in this quiet little town...  0.9537   positive
# 737  "Coalmont is a bit off the beaten path, but th...  0.9908   positive
# 738  "Awesome \\ud83d\\ude0e Wonderful Old Gold Min...  0.9679   positive
# 673  "We stayed in the Pioneer cabin for a week, wh...  0.9839   positive
# 674  "We stayed at Nimpo Lake Resort from July 6-9,...  0.9785   positive
# 675  "We only stayed two nights at Nimpo, the rest ...  0.9748   positive
# 676  "We spent one night in the aptly-named Birdwat...  0.9838   positive
# 677  "I revisited Nimpo Lake Resort after 14 years,...  0.7717   positive
# 678  "After a great time last year at Nimpo Lake Re...  0.9794   positive
# 679  "We booked the Nimpo Lake Resort online and we...  0.9229   positive
# 680  "We stayed at Nimpo Lake Resort in an RV site;...  0.9909   positive
# 681  "It\\'s not a hotel!\\nWe had a great time wit...  0.9607   positive
# 682  "We arrive on the 21st of June 2015.  The owne...  0.9493   positive
# 683  "Stunning, pristine lake! Fabulous fishing!!! ...  0.9981   positive
# 684  "Stayed here five nights.  The hospitality of ...  0.9500   positive
# 685  "we stayed two nights at Nimpo Lake Resort.  I...  0.7574   positive
# 686  "Stayed in the pioneer cabin.  Right on the la...  0.8268   positive
# 687  "The cabins contained all the comforts you nee...  0.9060   positive
# 688  "We stayed in the Birdwatcher\\'s Cabin for fi...  0.9929   positive
# 689  "My husband and I stayed at the Hilltop Cabin ...  0.9665   positive
# 690  "We had a wonderful stay at Nimpo Lake Resort....  0.9194   positive
# 691  "Completely fulfilled expectations! The cabin ...  0.9934   positive
# 692  "We we\\'re so lucky we drove up with out a re...  0.9394   positive
# 693  "Had the pleasure of staying at this resort a ...  0.9600   positive
# 694  "We recently enjoyed a few days at Nimpo Lake ...  0.9798   positive
#
#                       Hotel_Name  exp_index  Ratings
# 28   Stansbury&#39;s Guest House          1      5.0
# 29   Stansbury&#39;s Guest House          1      5.0
# 30   Stansbury&#39;s Guest House          1      5.0
# 31   Stansbury&#39;s Guest House          1      5.0
# 32   Stansbury&#39;s Guest House          1      5.0
# 33   Stansbury&#39;s Guest House          1      5.0
# 34   Stansbury&#39;s Guest House          1      5.0
# 35   Stansbury&#39;s Guest House          1      5.0
# 36   Stansbury&#39;s Guest House          1      5.0
# 37   Stansbury&#39;s Guest House          1      5.0
# 38   Stansbury&#39;s Guest House          1      5.0
# 39   Stansbury&#39;s Guest House          1      5.0
# 40   Stansbury&#39;s Guest House          1      5.0
# 41   Stansbury&#39;s Guest House          1      4.0
# 42   Stansbury&#39;s Guest House          1      5.0
# 43   Stansbury&#39;s Guest House          1      5.0
# 44   Stansbury&#39;s Guest House          1      5.0
# 45   Stansbury&#39;s Guest House          1      5.0
# 46   Stansbury&#39;s Guest House          1      5.0
# 47   Stansbury&#39;s Guest House          1      5.0
# 48   Stansbury&#39;s Guest House          1      5.0
# 49   Stansbury&#39;s Guest House          1      5.0
# 50   Stansbury&#39;s Guest House          1      5.0
# 51   Stansbury&#39;s Guest House          1      5.0
# 52   Stansbury&#39;s Guest House          1      5.0
# 53   Stansbury&#39;s Guest House          1      5.0
# 54   Stansbury&#39;s Guest House          1      5.0
# 55   Stansbury&#39;s Guest House          1      5.0
# 56   Stansbury&#39;s Guest House          1      5.0
# 57   Stansbury&#39;s Guest House          1      5.0
# ..                           ...        ...      ...
# 731                 Mozey-On-Inn          1      NaN
# 732                 Mozey-On-Inn          1      NaN
# 733                 Mozey-On-Inn          1      NaN
# 734                 Mozey-On-Inn          1      NaN
# 735                 Mozey-On-Inn          1      NaN
# 736                 Mozey-On-Inn          1      NaN
# 737                 Mozey-On-Inn          1      NaN
# 738                 Mozey-On-Inn          1      NaN
# 673            Nimpo Lake Resort          1      NaN
# 674            Nimpo Lake Resort          1      NaN
# 675            Nimpo Lake Resort          1      NaN
# 676            Nimpo Lake Resort          1      NaN
# 677            Nimpo Lake Resort          1      NaN
# 678            Nimpo Lake Resort          1      NaN
# 679            Nimpo Lake Resort          1      NaN
# 680            Nimpo Lake Resort          1      NaN
# 681            Nimpo Lake Resort          1      NaN
# 682            Nimpo Lake Resort          1      NaN
# 683            Nimpo Lake Resort          1      NaN
# 684            Nimpo Lake Resort          1      NaN
# 685            Nimpo Lake Resort          1      NaN
# 686            Nimpo Lake Resort          1      NaN
# 687            Nimpo Lake Resort          1      NaN
# 688            Nimpo Lake Resort          1      NaN
# 689            Nimpo Lake Resort          1      NaN
# 690            Nimpo Lake Resort          1      NaN
# 691            Nimpo Lake Resort          1      NaN
# 692            Nimpo Lake Resort          1      NaN
# 693            Nimpo Lake Resort          1      NaN
# 694            Nimpo Lake Resort          1      NaN
#
# [180 rows x 6 columns]

# %%
fig, ax = plt.subplots(figsize=(12,5))
plt.setp(plt.xticks()[1], rotation=90)
sns.catplot(x="Hotel_Name", y="exp_index", kind="box", data=gt_df4, ax = ax);
plt.close(2)
plt.title('Hotel reviews count')
ax.set(xlabel='Hotel names', ylabel='Count')

# Calculate number of obs per group & median to position labels
medians = gt_df4.groupby(['Hotel_Name'])['exp_index'].median().values
nobs = gt_df4['Hotel_Name'].value_counts().values
nobs = [str(x) for x in nobs.tolist()]
nobs = ["n: " + i for i in nobs]
 
# Add it to the plot
pos = range(len(nobs))
for tick,label in zip(pos,ax.get_xticklabels()):
    ax.text(pos[tick], medians[tick] + 0.03, nobs[tick],
horizontalalignment='center', size='large', color='b', weight='semibold')

plt.show()

# %%
fig, ax = plt.subplots(figsize=(12,5))
plt.setp(plt.xticks()[1], rotation=90)
sns.catplot(x="Hotel_Name", y="vader", kind="box", data=gt_df4, ax = ax);
plt.close(2)
plt.title('Hotel reviews count')
ax.set(xlabel='Hotel names', ylabel='Count')

# Calculate number of obs per group & median to position labels
medians = gt_df4.groupby(['Hotel_Name'])['vader'].median().values
nobs = gt_df4['Hotel_Name'].value_counts().values
nobs = [str(x) for x in nobs.tolist()]
nobs = ["n: " + i for i in nobs]
 
# Add it to the plot
pos = range(len(nobs))
for tick,label in zip(pos,ax.get_xticklabels()):
    ax.text(pos[tick], medians[tick] + 0.03, nobs[tick],
horizontalalignment='center', size='large', color='b', weight='semibold')



plt.show()

# %% [markdown]
# #### (b) Mean and variance of the ground truth and Vader sentiment scores for the  top-5 ranked hotels according to star rating
# The mean and the variance for the ground truth was the exact same score - one as all reviews they had gotten were positive. The boxplots for the vader scores were more informative. The variance score is more informative than the mean of the top five hotels. For example, Stamp Falls and Mozey-On-Inn are both highly rated hotels, however Stamp Falls has a higher number of people rated on it and most people had more positive comments to give than in Mozzey-On_Inn.

# %% [markdown]
# #### Variance:
# Vader: 0.010745 <br>
# Ratings: 0.0
# #### Mean:
# Vader: 0.94 <br>
# Ratings:1

# %% [markdown]
# #### (c) Scatterplots and heatmaps of ground truth score (star ratings) versus vader sentiment score.

# %%
temp = reviews_df['Ratings']
scatterDF = pd.concat([reviewDF,temp],axis = 1)
scatterDF.head()
cols = []
count = 1
for column in scatterDF.columns:
    if column == 'Ratings':
        cols.append('Ratings_'+str(count))
        count+=1
        continue
    cols.append(column)
scatterDF.columns = cols
scatterDF.head()
# Out:
#                                            reviewCol   vader Experience  \
# 0  "I was looking for a place to sit and chill fo...  0.8442   positive
# 1  "I stayed at the Riding Fool Hostel whilst I w...  0.9965   positive
# 2  "My husband and I (both in our 50\\'s) stayed ...  0.9757   positive
# 3  "We were warmly  welcomed by Caitlin, the new ...  0.9766   positive
# 4  "Comfortable, cheap, and cosy accommodation wi...  0.4939   positive
#
#                Hotel_Name  exp_index  Ratings_1  Ratings_2
# 0  The Riding Fool Hostel          1        NaN          5
# 1  The Riding Fool Hostel          1        NaN          5
# 2  The Riding Fool Hostel          1        NaN          5
# 3  The Riding Fool Hostel          1        NaN          5
# 4  The Riding Fool Hostel          1        NaN          5

# %%
fig, ax = plt.subplots(figsize=(12,5))
ax = sns.scatterplot(x="Ratings_2", y="vader", data=scatterDF)

# %%
R = scatterDF['Ratings_2'].values
V = scatterDF['vader'].values
#x, y = np.meshgrid(R, V)
from scipy.stats.kde import gaussian_kde
V
# Out:
# array([0.8442, 0.9965, 0.9757, ..., 0.9524, 0.1655, 0.9363])

# %%
#ax3 = sns.heatmap(np.log10(zi.reshape(xi.shape)),cmap=cmap)

# %%
from scipy.stats.kde import gaussian_kde

k = gaussian_kde(np.vstack([V, R]))
xi, yi = np.mgrid[V.min():V.max():V.size**0.5*1j,R.min():R.max():R.size**0.5*1j]
zi = k(np.vstack([xi.flatten(), yi.flatten()]))

# %%
cmap = sns.cubehelix_palette(light=1, as_cmap=True)
fig = plt.figure(figsize=(6,8))
ax1 = fig.add_subplot(211)
ax2 = fig.add_subplot(212)

ax1.pcolormesh(xi, yi, np.log10(zi.reshape(xi.shape)), cmap=cmap)
ax2.contourf(xi, yi, np.log10(zi.reshape(xi.shape)), cmap=cmap)

ax1.set_xlim(V.min(), V.max())
ax1.set_ylim(R.min(), R.max())
ax2.set_xlim(V.min(), V.max())
ax2.set_ylim(R.min(), R.max())

ax1.set_xlabel('Vader Score')
ax1.set_ylabel('Rating')

ax2.set_xlabel('Vader Score')
ax2.set_ylabel('Rating')
# Out:
# Text(0, 0.5, 'Rating')

# %% [markdown]
# The scatter plot of the ground truth versus vader score was not particularly informative on it own. The only interesting part about it was the for the higher ground through rating, the reviews (dots) were placed in the higher spectrum of the vader score. This idea in combination with the heatplot conveys the same idea, as the top right corner of the graph is a lot darker than the rest of the plot, which goes to show that those ratings had a higher vaderscore and a higher rating. And since we had established earlier, that most of the reviews had a higher vader score, the right half of the heat map is darker as that is the region with the most over lap between the high scores.

# %% [markdown]
# #### (b) Scatterplots and two heatmaps of the length of reviews versus each of ground truth score and Vader sentiment score. Each review is a point on the scatterplot.

# %%
review = scatterDF['reviewCol']
length = []

for r in review:
    length.append(len(r))
length_df = pd.Series(length) 
scatterDF1 = pd.concat([scatterDF,length_df.rename('length')],axis = 1)
scatterDF1.head()
# Out:
#                                            reviewCol   vader Experience  \
# 0  "I was looking for a place to sit and chill fo...  0.8442   positive
# 1  "I stayed at the Riding Fool Hostel whilst I w...  0.9965   positive
# 2  "My husband and I (both in our 50\\'s) stayed ...  0.9757   positive
# 3  "We were warmly  welcomed by Caitlin, the new ...  0.9766   positive
# 4  "Comfortable, cheap, and cosy accommodation wi...  0.4939   positive
#
#                Hotel_Name  exp_index  Ratings_1  Ratings_2  length
# 0  The Riding Fool Hostel          1        NaN          5     439
# 1  The Riding Fool Hostel          1        NaN          5    2666
# 2  The Riding Fool Hostel          1        NaN          5     509
# 3  The Riding Fool Hostel          1        NaN          5     673
# 4  The Riding Fool Hostel          1        NaN          5     384

# %%
fig, ax = plt.subplots(figsize=(12,5))
ax = sns.scatterplot(x="Ratings_1", y="length", data=scatterDF1)

# %%
fig, ax = plt.subplots(figsize=(12,5))
ax = sns.scatterplot(x="vader", y="length", data=scatterDF1)

# %%
x = scatterDF1['length']
y = scatterDF1['Ratings_2']
k = gaussian_kde(np.vstack([x, y]))
xi, yi = np.mgrid[x.min():x.max():x.size**0.5*1j,y.min():y.max():y.size**0.5*1j]
zi = k(np.vstack([xi.flatten(), yi.flatten()]))

# %%
cmap = sns.cubehelix_palette(light=1, as_cmap=True)
fig = plt.figure(figsize=(6,8))
ax1 = fig.add_subplot(211)
ax2 = fig.add_subplot(212)

ax1.pcolormesh(xi, yi, np.log10(zi.reshape(xi.shape)), cmap=cmap)
ax2.contourf(xi, yi, np.log10(zi.reshape(xi.shape)), cmap=cmap)

ax1.set_xlim(x.min(), x.max())
ax1.set_ylim(y.min(), y.max())
ax2.set_xlim(x.min(), x.max())
ax2.set_ylim(y.min(), y.max())

ax1.set_xlabel('Length')
ax1.set_ylabel('Rating')

ax2.set_xlabel('Length')
ax2.set_ylabel('Rating')
# Out:
# Text(0, 0.5, 'Rating')

# %%
fig = plt.figure(figsize=(6,8))
ax3 = sns.heatmap(np.log10(zi.reshape(xi.shape)),cmap=cmap)

# %% [markdown]
# The scatterplot tells us that most reviews are at a lower character length (about 2000 characters or lower) and this is reflected in the heat map, as most the color becomes lighter past review length of 1500 characters. Further more, there are a few tweets of character length 4000 or higher and this is reflected in the small light patch along that character length and review rating of 4.

# %%
x = scatterDF1['length']
y = scatterDF1['vader']
k = gaussian_kde(np.vstack([x, y]))
xi, yi = np.mgrid[x.min():x.max():x.size**0.5*1j,y.min():y.max():y.size**0.5*1j]
zi = k(np.vstack([xi.flatten(), yi.flatten()]))

# %%
cmap = sns.cubehelix_palette(light=1, as_cmap=True)
fig = plt.figure(figsize=(6,8))
ax1 = fig.add_subplot(211)
ax2 = fig.add_subplot(212)

ax1.pcolormesh(xi, yi, np.log10(zi.reshape(xi.shape)), cmap=cmap)
ax2.contourf(xi, yi, np.log10(zi.reshape(xi.shape)), cmap=cmap)

ax1.set_xlim(x.min(), x.max())
ax1.set_ylim(y.min(), y.max())
ax2.set_xlim(x.min(), x.max())
ax2.set_ylim(y.min(), y.max())

ax1.set_xlabel('Length')
ax1.set_ylabel('Vader')

ax2.set_xlabel('Length')
ax2.set_ylabel('Vader')
# Out:
# Text(0, 0.5, 'Vader')

# %%
fig = plt.figure(figsize=(6,8))
ax3 = sns.heatmap(np.log10(zi.reshape(yi.shape)),cmap=cmap)

# %% [markdown]
# The scatter plot for the vader score was the opposite of the ratings where, the higher the score (more positive) a score, the more characters were used in the review. However the patterns of the vader score match that of the heat plot where the lower the score, the less number of characters were used in the review of the hotel.

# %% [markdown]
# #### (c) Scatterplots of the number of reviews per hotel versus each of average groundtruth score and average Vader sentiment score. In this case, each hotel is a single point on the scatterplot.

# %%
avg_sort =  avg_rating.sort_values(['vader'], ascending=[1])

x = list(avg_sort.index)
vad = list(avg_sort['vader'].values)
exp = list(avg_sort['exp_index'].values)
x_DF = pd.DataFrame(x)
df = pd.DataFrame({'average_vader':vad, 'average_exp':exp, 'HotelName': x})

# %%
import pylab

# %%
fig, ax = plt.subplots(figsize=(17,5))
ax = sns.scatterplot(x="average_vader", y="average_exp",hue = 'HotelName', data=df)
pylab.legend(loc=9, bbox_to_anchor=(0.5, -0.1))

# %% [markdown]
# There is a positive linear pattern between the average vader scores and the average ratings per hotel, which suggest that even if the two scores are not linearly connected,they are still however dependent on each other.
